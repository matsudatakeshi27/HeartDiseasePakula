# %%
import numpy as np
import random
import cv2
import os
from imutils import paths
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K



def load(paths, verbose=-1):
    '''expects images for each class in seperate dir, 
    e.g all digits in 0 class in the directory named 0 '''
    data = list()
    labels = list()
    # loop over the input images
    for (i, imgpath) in enumerate(paths):
        # load the image and extract the class labels
        im_gray = cv2.imread(imgpath, cv2.IMREAD_GRAYSCALE)
        image = np.array(im_gray).flatten()
        label = imgpath.split(os.path.sep)[-2]
        # scale the image to [0, 1] and add to list
        data.append(image/255)
        labels.append(label)
        # show an update every `verbose` images
        if verbose > 0 and i > 0 and (i + 1) % verbose == 0:
            print("[INFO] processed {}/{}".format(i + 1, len(paths)))
    # return a tuple of the data and labels
    return data, labels


def create_clients(image_list, label_list, num_clients=10, initial='clients'):
    ''' return: a dictionary with keys clients' names and value as 
                data shards - tuple of images and label lists.
        args: 
            image_list: a list of numpy arrays of training images
            label_list:a list of binarized labels for each image
            num_client: number of fedrated members (clients)
            initials: the clients'name prefix, e.g, clients_1 
            
    '''

    #create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]

    #randomize the data
    data = list(zip(image_list, label_list))
    random.shuffle(data)

    #shard data and place at each client
    size = len(data)//num_clients
    shards = [data[i:i + size] for i in range(0, size*num_clients, size)]

    #number of clients must equal number of shards
    assert(len(shards) == len(client_names))

    return {client_names[i] : shards[i] for i in range(len(client_names))}



def batch_data(data_shard, bs=32):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    return dataset.shuffle(len(label)).batch(bs)


class SimpleMLP:
    @staticmethod
    def build(shape, classes):
        model = Sequential()
        model.add(Dense(200, input_shape=(shape,)))
        model.add(Activation("relu"))
        model.add(Dense(200))
        model.add(Activation("relu"))
        model.add(Dense(classes))
        model.add(Activation("softmax"))
        return model
    

def weight_scalling_factor(clients_trn_data, client_name):
    client_names = list(clients_trn_data.keys())
    #get the bs
    bs = list(clients_trn_data[client_name])[0][0].shape[0]
    #first calculate the total training data points across clinets
    global_count = sum([tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy() for client_name in client_names])*bs
    # get the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy()*bs
    return local_count/global_count


def scale_model_weights(weight, scalar):
    '''function for scaling a models weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final



def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights. The is equivalent to scaled avg of the weights'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
        
    return avg_grad


def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    loss = cce(Y_test, logits)
    acc = accuracy_score(tf.argmax(logits, axis=1), tf.argmax(Y_test, axis=1))
    print('comm_round: {} | global_acc: {:.3%} | global_loss: {}'.format(comm_round, acc, loss))
    return acc, loss

# %%
import numpy as np
import random
import cv2
import os
from imutils import paths
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

from tensorflow.keras import backend as K

#from fl_mnist_implementation_tutorial_utils import *

#declear path to your mnist data folder
img_path = 'trainingSample/trainingSample'

#get the path list using the path object
image_paths = list(paths.list_images(img_path))

#apply our function
image_list, label_list = load(image_paths, verbose=10000)

#binarize the labels
lb = LabelBinarizer()
label_list = lb.fit_transform(label_list)

#split data into training and test set
X_train, X_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.1, random_state=42)

#create clients
clients = create_clients(X_train, y_train, num_clients=10, initial='client')

#process and batch the training data for each client
clients_batched = dict()
for (client_name, data) in clients.items():
    clients_batched[client_name] = batch_data(data)
    
#process and batch the test set  
test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

comms_round = 100
    
#create optimizer
lr = 0.01 
loss='categorical_crossentropy'
metrics = ['accuracy']
optimizer = tf.keras.optimizers.legacy.SGD(lr=lr, decay=lr / comms_round, momentum=0.9) 

#initialize global model
smlp_global = SimpleMLP()
global_model = smlp_global.build(784, 10)
        
#commence global training loop
for comm_round in range(comms_round):
            
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()
    
    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(clients_batched.keys())
    random.shuffle(client_names)
    
    #loop through each client and create new local model
    for client in client_names:
        smlp_local = SimpleMLP()
        local_model = smlp_local.build(784, 10)
        local_model.compile(loss=loss, 
                      optimizer=optimizer, 
                      metrics=metrics)
        
        #set local model weight to the weight of the global model
        local_model.set_weights(global_weights)
        
        #fit local model with client's data
        local_model.fit(clients_batched[client], epochs=1, verbose=0)
        
        #scale the model weights and add to list
        scaling_factor = weight_scalling_factor(clients_batched, client)
        scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
        scaled_local_weight_list.append(scaled_weights)
        
        #clear session to free memory after each communication round
        K.clear_session()
        
    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)
    
    #update global model 
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    for(X_test, Y_test) in test_batched:
        global_acc, global_loss = test_model(X_test, Y_test, global_model, comm_round)
        SGD_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(len(y_train)).batch(320)
        smlp_SGD = SimpleMLP()
        SGD_model = smlp_SGD.build(784, 10) 

        SGD_model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# fit the SGD training data to model
_ = SGD_model.fit(SGD_dataset, epochs=100, verbose=0)

#test the SGD global model and print out metrics
for(X_test, Y_test) in test_batched:
        SGD_acc, SGD_loss = test_model(X_test, Y_test, SGD_model, 1)
# Out:
# D:\Anaconda\envs\GPU\lib\site-packages\keras\optimizers\legacy\gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_train_function.<locals>.train_function at 0x00000220597AF700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_train_function.<locals>.train_function at 0x00000220597AF700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x00000220598693A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x00000220598693A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 998us/step
# comm_round: 0 | global_acc: 13.333% | global_loss: 2.2992475032806396
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 1 | global_acc: 13.333% | global_loss: 2.297719717025757
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 2 | global_acc: 15.000% | global_loss: 2.29621958732605
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 3 | global_acc: 15.000% | global_loss: 2.2946391105651855
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 4 | global_acc: 16.667% | global_loss: 2.2930748462677
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 5 | global_acc: 16.667% | global_loss: 2.29150390625
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 6 | global_acc: 16.667% | global_loss: 2.289868116378784
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 7 | global_acc: 16.667% | global_loss: 2.2882161140441895
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 8 | global_acc: 20.000% | global_loss: 2.286543369293213
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 9 | global_acc: 21.667% | global_loss: 2.2848289012908936
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 10 | global_acc: 23.333% | global_loss: 2.283032178878784
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 11 | global_acc: 23.333% | global_loss: 2.281261682510376
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 12 | global_acc: 26.667% | global_loss: 2.2794363498687744
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 13 | global_acc: 28.333% | global_loss: 2.277578115463257
# 2/2 [==============================] - 0s 3ms/step
# comm_round: 14 | global_acc: 31.667% | global_loss: 2.275709390640259
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 15 | global_acc: 31.667% | global_loss: 2.2738277912139893
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 16 | global_acc: 33.333% | global_loss: 2.271895408630371
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 17 | global_acc: 35.000% | global_loss: 2.2698638439178467
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 18 | global_acc: 36.667% | global_loss: 2.267765998840332
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 19 | global_acc: 40.000% | global_loss: 2.26566219329834
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 20 | global_acc: 45.000% | global_loss: 2.2635483741760254
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 21 | global_acc: 48.333% | global_loss: 2.2614121437072754
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 22 | global_acc: 48.333% | global_loss: 2.259260892868042
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 23 | global_acc: 48.333% | global_loss: 2.2570888996124268
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 24 | global_acc: 50.000% | global_loss: 2.2548060417175293
# 2/2 [==============================] - 0s 1000us/step
# comm_round: 25 | global_acc: 50.000% | global_loss: 2.2524726390838623
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 26 | global_acc: 53.333% | global_loss: 2.2501413822174072
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 27 | global_acc: 53.333% | global_loss: 2.2476656436920166
# 2/2 [==============================] - 0s 1ms/step
# comm_round: 28 | global_acc: 53.333% | global_loss: 2.2451095581054688
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 29 | global_acc: 55.000% | global_loss: 2.242598295211792
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 30 | global_acc: 56.667% | global_loss: 2.2399511337280273
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 31 | global_acc: 58.333% | global_loss: 2.2371363639831543
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 32 | global_acc: 58.333% | global_loss: 2.2344348430633545
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 33 | global_acc: 60.000% | global_loss: 2.2315754890441895
# 2/2 [==============================] - 0s 1ms/step
# comm_round: 34 | global_acc: 65.000% | global_loss: 2.2287609577178955
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 35 | global_acc: 68.333% | global_loss: 2.2257742881774902
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 36 | global_acc: 66.667% | global_loss: 2.222752332687378
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 37 | global_acc: 66.667% | global_loss: 2.2196767330169678
# 2/2 [==============================] - 0s 1ms/step
# comm_round: 38 | global_acc: 70.000% | global_loss: 2.216439723968506
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 39 | global_acc: 70.000% | global_loss: 2.2132601737976074
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 40 | global_acc: 70.000% | global_loss: 2.2100555896759033
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 41 | global_acc: 70.000% | global_loss: 2.206731081008911
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 42 | global_acc: 71.667% | global_loss: 2.203357696533203
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 43 | global_acc: 71.667% | global_loss: 2.200031280517578
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 44 | global_acc: 71.667% | global_loss: 2.1966023445129395
# 2/2 [==============================] - 0s 1ms/step
# comm_round: 45 | global_acc: 71.667% | global_loss: 2.193027973175049
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 46 | global_acc: 71.667% | global_loss: 2.189476490020752
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 47 | global_acc: 70.000% | global_loss: 2.185835838317871
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 48 | global_acc: 70.000% | global_loss: 2.182091236114502
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 49 | global_acc: 71.667% | global_loss: 2.178295850753784
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 50 | global_acc: 71.667% | global_loss: 2.1745388507843018
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 51 | global_acc: 71.667% | global_loss: 2.170578956604004
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 52 | global_acc: 73.333% | global_loss: 2.1665613651275635
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 53 | global_acc: 75.000% | global_loss: 2.162571668624878
# 2/2 [==============================] - 0s 1ms/step
# comm_round: 54 | global_acc: 76.667% | global_loss: 2.1584255695343018
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 55 | global_acc: 76.667% | global_loss: 2.154303550720215
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 56 | global_acc: 76.667% | global_loss: 2.1500742435455322
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 57 | global_acc: 76.667% | global_loss: 2.1461896896362305
# 2/2 [==============================] - 0s 1ms/step
# comm_round: 58 | global_acc: 76.667% | global_loss: 2.1419365406036377
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 59 | global_acc: 76.667% | global_loss: 2.137847423553467
# 2/2 [==============================] - 0s 1ms/step
# comm_round: 60 | global_acc: 76.667% | global_loss: 2.133580446243286
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 61 | global_acc: 76.667% | global_loss: 2.129464626312256
# 2/2 [==============================] - 0s 1ms/step
# comm_round: 62 | global_acc: 76.667% | global_loss: 2.1253790855407715
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 63 | global_acc: 76.667% | global_loss: 2.1212007999420166
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 64 | global_acc: 76.667% | global_loss: 2.116894245147705
# 2/2 [==============================] - 0s 1ms/step
# comm_round: 65 | global_acc: 76.667% | global_loss: 2.112687587738037
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 66 | global_acc: 76.667% | global_loss: 2.108706474304199
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 67 | global_acc: 76.667% | global_loss: 2.104292392730713
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 68 | global_acc: 76.667% | global_loss: 2.0999884605407715
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 69 | global_acc: 76.667% | global_loss: 2.0956718921661377
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 70 | global_acc: 78.333% | global_loss: 2.091461420059204
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 71 | global_acc: 78.333% | global_loss: 2.0869946479797363
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 72 | global_acc: 78.333% | global_loss: 2.082498073577881
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 73 | global_acc: 78.333% | global_loss: 2.0783305168151855
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 74 | global_acc: 76.667% | global_loss: 2.0741944313049316
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 75 | global_acc: 76.667% | global_loss: 2.069892406463623
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 76 | global_acc: 76.667% | global_loss: 2.0657424926757812
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 77 | global_acc: 76.667% | global_loss: 2.061497926712036
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 78 | global_acc: 76.667% | global_loss: 2.057422399520874
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 79 | global_acc: 75.000% | global_loss: 2.0532047748565674
# 2/2 [==============================] - 0s 3ms/step
# comm_round: 80 | global_acc: 75.000% | global_loss: 2.0490660667419434
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 81 | global_acc: 75.000% | global_loss: 2.044909715652466
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 82 | global_acc: 75.000% | global_loss: 2.040837049484253
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 83 | global_acc: 75.000% | global_loss: 2.036874294281006
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 84 | global_acc: 75.000% | global_loss: 2.0328030586242676
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 85 | global_acc: 75.000% | global_loss: 2.02880859375
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 86 | global_acc: 75.000% | global_loss: 2.024906873703003
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 87 | global_acc: 75.000% | global_loss: 2.0210320949554443
# 2/2 [==============================] - 0s 3ms/step
# comm_round: 88 | global_acc: 75.000% | global_loss: 2.017209768295288
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 89 | global_acc: 75.000% | global_loss: 2.0134549140930176
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 90 | global_acc: 75.000% | global_loss: 2.0096752643585205
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 91 | global_acc: 75.000% | global_loss: 2.0060980319976807
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 92 | global_acc: 75.000% | global_loss: 2.0023906230926514
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 93 | global_acc: 75.000% | global_loss: 1.9990283250808716
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 94 | global_acc: 75.000% | global_loss: 1.9954657554626465
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 95 | global_acc: 76.667% | global_loss: 1.9920754432678223
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 96 | global_acc: 76.667% | global_loss: 1.9885176420211792
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 97 | global_acc: 76.667% | global_loss: 1.9849472045898438
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 98 | global_acc: 76.667% | global_loss: 1.9812188148498535
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 99 | global_acc: 76.667% | global_loss: 1.9779469966888428
# 2/2 [==============================] - 0s 2ms/step
# comm_round: 1 | global_acc: 80.000% | global_loss: 1.6820721626281738
