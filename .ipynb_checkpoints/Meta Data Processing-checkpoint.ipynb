# %%
import numpy as np
import pandas as pd
import keras.backend as K
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf

# %%
def CNN(path_train,path_test):
    #Split the data
    Train = pd.read_csv(path_train)
    Test = pd.read_csv(path_test)
    
    X_train = Train.iloc[:,:-1]
    Y_train = Train.iloc[:,-1]

    X_test = Test.iloc[:,:-1]
    Y_test = Test.iloc[:,-1]

    #binarize the target
    Y_train_binary = Y_train.apply(lambda x: 1 if x > 0 else 0)
    Y_test_binary = Y_test.apply(lambda x: 1 if x > 0 else 0)

    # define the model architecture
    model = Sequential()
    model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(22,1)))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(2, activation='sigmoid'))

    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(X_train, Y_train_binary, epochs=10, batch_size=32)
    Y_pred = model.predict(X_test).argmax(axis=1)
    
    cm = confusion_matrix(Y_pred, Y_test_binary)
    print(cm)
    print(classification_report(Y_test_binary, Y_pred))
    return model

def wholeData(path_train,path_test):
    #Split the data
    Train = pd.read_csv(path_train)
    Test = pd.read_csv(path_test)
    
    X_train = Train.iloc[:,:-1]
    Y_train = Train.iloc[:,-1]
    
    X_test = Test.iloc[:,:-1]
    Y_test = Test.iloc[:,-1]
    
    X_entire = pd.concat([X_train,X_test])
    Y_entire = pd.concat([Y_train,Y_test])
    return X_entire,Y_entire

# %% [markdown]
# # Cleveland

# %%
path_train = './TrainTestData/cle_train.csv'
path_test = './TrainTestData/cle_test.csv'
model = CNN(path_train,path_test)

model2 = Sequential()
model2.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(22,1)))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Flatten())
model2.add(Dense(128, activation='relu'))

model2.set_weights(model.get_weights()[:-2]) 

model2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

X_entire,labels = wholeData(path_train,path_test)

Y_predictions = model2.predict(X_entire)
Y_predictions.shape

temp = pd.DataFrame(Y_predictions)

labels = labels.reset_index()
labels = labels.drop(columns = ['index'])

cle_processed = pd.concat([temp,labels],axis = 1)

cle_processed.to_csv('cle_metadata.csv',index = False)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6557 - accuracy: 0.5613
# Epoch 2/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5916 - accuracy: 0.6604
# Epoch 3/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5043 - accuracy: 0.7358
# Epoch 4/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4406 - accuracy: 0.7925
# Epoch 5/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3924 - accuracy: 0.8208
# Epoch 6/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3743 - accuracy: 0.8160
# Epoch 7/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3543 - accuracy: 0.8491
# Epoch 8/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3343 - accuracy: 0.8632
# Epoch 9/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3317 - accuracy: 0.8302
# Epoch 10/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3220 - accuracy: 0.8538
# 3/3 [==============================] - 0s 3ms/step
# [[41  8]
#  [10 32]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82        51
#            1       0.76      0.80      0.78        40
#
#     accuracy                           0.80        91
#    macro avg       0.80      0.80      0.80        91
# weighted avg       0.80      0.80      0.80        91
#
# 10/10 [==============================] - 0s 2ms/step

# %% [markdown]
# # Virginia

# %%
path_train = './TrainTestData/vir_train.csv'
path_test = './TrainTestData/vir_test.csv'
model = CNN(path_train,path_test)

model2 = Sequential()
model2.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(22,1)))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Flatten())
model2.add(Dense(128, activation='relu'))

model2.set_weights(model.get_weights()[:-2]) 

model2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

X_entire,labels = wholeData(path_train,path_test)

Y_predictions = model2.predict(X_entire)
Y_predictions.shape

temp = pd.DataFrame(Y_predictions)

labels = labels.reset_index()
labels = labels.drop(columns = ['index'])

cle_processed = pd.concat([temp,labels],axis = 1)

cle_processed.to_csv('vir_metadata.csv',index = False)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6488 - accuracy: 0.7286
# Epoch 2/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5643 - accuracy: 0.7286
# Epoch 3/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5467 - accuracy: 0.7286
# Epoch 4/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5405 - accuracy: 0.7286
# Epoch 5/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5251 - accuracy: 0.7286
# Epoch 6/10
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5089 - accuracy: 0.7429
# Epoch 7/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4966 - accuracy: 0.7714
# Epoch 8/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4840 - accuracy: 0.7857
# Epoch 9/10
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4800 - accuracy: 0.7786
# Epoch 10/10
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5045 - accuracy: 0.7714
# 2/2 [==============================] - 0s 3ms/step
# [[ 2  0]
#  [11 47]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.15      0.27        13
#            1       0.81      1.00      0.90        47
#
#     accuracy                           0.82        60
#    macro avg       0.91      0.58      0.58        60
# weighted avg       0.85      0.82      0.76        60
#
# 7/7 [==============================] - 0s 2ms/step

# %% [markdown]
# # Hungarian

# %%
path_train = './TrainTestData/hun_train.csv'
path_test = './TrainTestData/hun_test.csv'
model = CNN(path_train,path_test)

model2 = Sequential()
model2.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(22,1)))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Flatten())
model2.add(Dense(128, activation='relu'))

model2.set_weights(model.get_weights()[:-2]) 

model2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

X_entire,labels = wholeData(path_train,path_test)

Y_predictions = model2.predict(X_entire)
Y_predictions.shape

temp = pd.DataFrame(Y_predictions)

labels = labels.reset_index()
labels = labels.drop(columns = ['index'])

cle_processed = pd.concat([temp,labels],axis = 1)

cle_processed.to_csv('hun_metadata.csv',index = False)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5997 - accuracy: 0.6585
# Epoch 2/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4026 - accuracy: 0.8195
# Epoch 3/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3414 - accuracy: 0.8585
# Epoch 4/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4623 - accuracy: 0.7854
# Epoch 5/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4068 - accuracy: 0.8195
# Epoch 6/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3463 - accuracy: 0.8244
# Epoch 7/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3140 - accuracy: 0.8780
# Epoch 8/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2990 - accuracy: 0.8683
# Epoch 9/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2837 - accuracy: 0.9024
# Epoch 10/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2713 - accuracy: 0.8829
# 3/3 [==============================] - 0s 3ms/step
# [[53  9]
#  [ 4 23]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89        57
#            1       0.85      0.72      0.78        32
#
#     accuracy                           0.85        89
#    macro avg       0.85      0.82      0.84        89
# weighted avg       0.85      0.85      0.85        89
#
# 10/10 [==============================] - 0s 2ms/step

# %% [markdown]
# # Switzerland

# %%
path_train = './TrainTestData/swi_train.csv'
path_test = './TrainTestData/swi_test.csv'
model = CNN(path_train,path_test)

model2 = Sequential()
model2.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(22,1)))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Flatten())
model2.add(Dense(128, activation='relu'))

model2.set_weights(model.get_weights()[:-2]) 

model2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

X_entire,labels = wholeData(path_train,path_test)

Y_predictions = model2.predict(X_entire)
Y_predictions.shape

temp = pd.DataFrame(Y_predictions)

labels = labels.reset_index()
labels = labels.drop(columns = ['index'])

cle_processed = pd.concat([temp,labels],axis = 1)

cle_processed.to_csv('swi_metadata.csv',index = False)
# Out:
# Epoch 1/10
# 3/3 [==============================] - 1s 11ms/step - loss: 0.5155 - accuracy: 0.6512
# Epoch 2/10
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2762 - accuracy: 0.9302
# Epoch 3/10
# 3/3 [==============================] - 0s 11ms/step - loss: 0.3014 - accuracy: 0.9302
# Epoch 4/10
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2643 - accuracy: 0.9302
# Epoch 5/10
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2414 - accuracy: 0.9302
# Epoch 6/10
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2442 - accuracy: 0.9302
# Epoch 7/10
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2315 - accuracy: 0.9302
# Epoch 8/10
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2244 - accuracy: 0.9302
# Epoch 9/10
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2297 - accuracy: 0.9302
# Epoch 10/10
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2197 - accuracy: 0.9302
# 2/2 [==============================] - 0s 2ms/step
# [[ 0  0]
#  [ 2 35]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.95      1.00      0.97        35
#
#     accuracy                           0.95        37
#    macro avg       0.47      0.50      0.49        37
# weighted avg       0.89      0.95      0.92        37
#
# 4/4 [==============================] - 0s 3ms/step
# D:\Anaconda\envs\GPU\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\envs\GPU\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\envs\GPU\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
