# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %% [markdown]
# # RNN metadata:

# %%
cle = pd.read_csv('cle_metadata_rnn.csv')
vir = pd.read_csv('vir_metadata_rnn.csv')
hun = pd.read_csv('hun_metadata_rnn.csv')
swi = pd.read_csv('swi_metadata_rnn.csv')

# %%
cle_train,cle_test = train_test_split(cle,test_size=0.33, random_state=42)
vir_train,vir_test = train_test_split(vir,test_size=0.33, random_state=42)
hun_train,hun_test = train_test_split(hun,test_size=0.33, random_state=42)
swi_train,swi_test = train_test_split(swi,test_size=0.33, random_state=42)

# %%
cle_train.to_csv('cle_metadata_rnn_train.csv',index = False)
cle_test.to_csv('cle_metadata_rnn_test.csv',index = False)

# %%
vir_train.to_csv('vir_metadata_rnn_train.csv',index = False)
vir_test.to_csv('vir_metadata_rnn_test.csv',index = False)

# %%
hun_train.to_csv('hun_metadata_rnn_train.csv',index = False)
hun_test.to_csv('hun_metadata_rnn_test.csv',index = False)

# %%
swi_train.to_csv('swi_metadata_rnn_train.csv',index = False)
swi_test.to_csv('swi_metadata_rnn_test.csv',index = False)

# %%
Train = pd.concat([cle_train,vir_train,hun_train,swi_train])
Test = pd.concat([cle_test,vir_test,hun_test,swi_test])

# %%
X_train = Train.iloc[:,:-1]
X_test = Test.iloc[:,:-1]

y_train = Train.iloc[:,-1]
y_test = Test.iloc[:,-1]

Y_train_binary = y_train.apply(lambda x: 1 if x > 0 else 0)
Y_test_binary = y_test.apply(lambda x: 1 if x > 0 else 0)

# %% [markdown]
# # CNN

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

# define the model architecture
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(64,1)))
model.add(Conv1D(filters=256, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

model.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
model.fit(X_train, Y_train_binary, epochs=1000, batch_size=32,callbacks=[callback])
Y_pred = model.predict(X_test).argmax(axis=1)
    
cm = confusion_matrix(Y_pred, Y_test_binary)
print(cm)
print(classification_report(Y_test_binary, Y_pred, digits=4))
# Out:
# Epoch 1/1000
# 20/20 [==============================] - 2s 63ms/step - loss: 0.6697 - accuracy: 0.6114
# Epoch 2/1000
# 20/20 [==============================] - 1s 65ms/step - loss: 0.4766 - accuracy: 0.7691
# Epoch 3/1000
# 20/20 [==============================] - 1s 67ms/step - loss: 0.4725 - accuracy: 0.7919
# Epoch 4/1000
# 20/20 [==============================] - 1s 71ms/step - loss: 0.4084 - accuracy: 0.8228
# Epoch 5/1000
# 20/20 [==============================] - 1s 65ms/step - loss: 0.3899 - accuracy: 0.8374
# Epoch 6/1000
# 20/20 [==============================] - 1s 73ms/step - loss: 0.3826 - accuracy: 0.8407
# Epoch 7/1000
# 20/20 [==============================] - 1s 65ms/step - loss: 0.3597 - accuracy: 0.8455
# Epoch 8/1000
# 20/20 [==============================] - 1s 66ms/step - loss: 0.3559 - accuracy: 0.8472
# Epoch 9/1000
# 20/20 [==============================] - 1s 64ms/step - loss: 0.3406 - accuracy: 0.8699
# Epoch 10/1000
# 20/20 [==============================] - 1s 63ms/step - loss: 0.3960 - accuracy: 0.8374
# Epoch 11/1000
# 20/20 [==============================] - 1s 65ms/step - loss: 0.3383 - accuracy: 0.8585
# Epoch 12/1000
# 20/20 [==============================] - 1s 62ms/step - loss: 0.3034 - accuracy: 0.8715
# Epoch 13/1000
# 20/20 [==============================] - 1s 66ms/step - loss: 0.2972 - accuracy: 0.8797
# Epoch 14/1000
# 20/20 [==============================] - 2s 95ms/step - loss: 0.2768 - accuracy: 0.8911
# Epoch 15/1000
# 20/20 [==============================] - 1s 66ms/step - loss: 0.2758 - accuracy: 0.8927
# Epoch 16/1000
# 20/20 [==============================] - 1s 66ms/step - loss: 0.2966 - accuracy: 0.8748
# Epoch 17/1000
# 20/20 [==============================] - 1s 67ms/step - loss: 0.2492 - accuracy: 0.8943
# Epoch 18/1000
# 20/20 [==============================] - 1s 68ms/step - loss: 0.2472 - accuracy: 0.9041
# Epoch 19/1000
# 20/20 [==============================] - 2s 95ms/step - loss: 0.2590 - accuracy: 0.8862
# Epoch 20/1000
# 20/20 [==============================] - 1s 62ms/step - loss: 0.2352 - accuracy: 0.8976
# Epoch 21/1000
# 20/20 [==============================] - 1s 61ms/step - loss: 0.2101 - accuracy: 0.9220
# Epoch 22/1000
# 20/20 [==============================] - 1s 63ms/step - loss: 0.1912 - accuracy: 0.9268
# Epoch 23/1000
# 20/20 [==============================] - 1s 62ms/step - loss: 0.2025 - accuracy: 0.9285
# Epoch 24/1000
# 20/20 [==============================] - 1s 65ms/step - loss: 0.2097 - accuracy: 0.9203
# Epoch 25/1000
# 20/20 [==============================] - 1s 70ms/step - loss: 0.1824 - accuracy: 0.9268
# Epoch 26/1000
# 20/20 [==============================] - 2s 80ms/step - loss: 0.1684 - accuracy: 0.9431
# Epoch 27/1000
# 20/20 [==============================] - 1s 61ms/step - loss: 0.1483 - accuracy: 0.9496
# Epoch 28/1000
# 20/20 [==============================] - 1s 63ms/step - loss: 0.1900 - accuracy: 0.9350
# Epoch 29/1000
# 20/20 [==============================] - 1s 63ms/step - loss: 0.1699 - accuracy: 0.9398
# Epoch 30/1000
# 20/20 [==============================] - 1s 61ms/step - loss: 0.1652 - accuracy: 0.9366
# Epoch 31/1000
# 20/20 [==============================] - 1s 70ms/step - loss: 0.1438 - accuracy: 0.9463
# Epoch 32/1000
# 20/20 [==============================] - 1s 69ms/step - loss: 0.1258 - accuracy: 0.9577
# Epoch 33/1000
# 20/20 [==============================] - 2s 77ms/step - loss: 0.1156 - accuracy: 0.9610
# Epoch 34/1000
# 20/20 [==============================] - 2s 89ms/step - loss: 0.1153 - accuracy: 0.9545
# Epoch 35/1000
# 20/20 [==============================] - 2s 95ms/step - loss: 0.1717 - accuracy: 0.9398
# Epoch 36/1000
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1184 - accuracy: 0.9626
# Epoch 37/1000
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0877 - accuracy: 0.9724
# Epoch 38/1000
# 20/20 [==============================] - 2s 122ms/step - loss: 0.0683 - accuracy: 0.9756
# Epoch 39/1000
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0819 - accuracy: 0.9659
# Epoch 40/1000
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1651 - accuracy: 0.9415
# Epoch 41/1000
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1415 - accuracy: 0.9463
# Epoch 42/1000
# 20/20 [==============================] - 2s 85ms/step - loss: 0.0823 - accuracy: 0.9707
# Epoch 43/1000
# 20/20 [==============================] - 2s 108ms/step - loss: 0.0725 - accuracy: 0.9707
# [[ 84  21]
#  [ 46 154]]
#               precision    recall  f1-score   support
#
#            0     0.8000    0.6462    0.7149       130
#            1     0.7700    0.8800    0.8213       175
#
#     accuracy                         0.7803       305
#    macro avg     0.7850    0.7631    0.7681       305
# weighted avg     0.7828    0.7803    0.7760       305

# %%
model.save('../Models/Meta_Only/RNNMeta_CNN.h5')

# %% [markdown]
# # Test on Each Data Set

# %%
def Test(path_train,path_test,model_name):
    Train = pd.read_csv(path_train)
    Test = pd.read_csv(path_test)

    X_train = Train.iloc[:,:-1]
    Y_train = Train.iloc[:,-1]

    X_test = Test.iloc[:,:-1]
    Y_test = Test.iloc[:,-1]

    #binarize the target
    Y_train_binary = Y_train.apply(lambda x: 1 if x > 0 else 0)
    Y_test_binary = Y_test.apply(lambda x: 1 if x > 0 else 0)

    model = tf.keras.models.load_model(model_name)

    Y_pred = model.predict(X_test).argmax(axis=1)

    cm = confusion_matrix(Y_pred, Y_test_binary)
    print(cm)
    print(classification_report(Y_test_binary, Y_pred, digits=4))

# %% [markdown]
# # Cleveland

# %%
path_train = 'cle_metadata_rnn_train.csv'
path_test = 'cle_metadata_rnn_test.csv'
model = '../Models/Meta_Only/RNNMeta_CNN.h5'
Test(path_train,path_test,model)
# Out:
# [[34  3]
#  [18 45]]
#               precision    recall  f1-score   support
#
#            0     0.9189    0.6538    0.7640        52
#            1     0.7143    0.9375    0.8108        48
#
#     accuracy                         0.7900       100
#    macro avg     0.8166    0.7957    0.7874       100
# weighted avg     0.8207    0.7900    0.7865       100

# %% [markdown]
# # Virginia

# %%
path_train = 'vir_metadata_rnn_train.csv'
path_test = 'vir_metadata_rnn_test.csv'
model = '../Models/Meta_Only/RNNMeta_CNN.h5'
Test(path_train,path_test,model)
# Out:
# [[ 5 10]
#  [10 41]]
#               precision    recall  f1-score   support
#
#            0     0.3333    0.3333    0.3333        15
#            1     0.8039    0.8039    0.8039        51
#
#     accuracy                         0.6970        66
#    macro avg     0.5686    0.5686    0.5686        66
# weighted avg     0.6970    0.6970    0.6970        66

# %% [markdown]
# # Hungarian

# %%
path_train = 'hun_metadata_rnn_train.csv'
path_test = 'hun_metadata_rnn_test.csv'
model = '../Models/Meta_Only/RNNMeta_CNN.h5'
Test(path_train,path_test,model)
# Out:
# [[45  8]
#  [15 30]]
#               precision    recall  f1-score   support
#
#            0     0.8491    0.7500    0.7965        60
#            1     0.6667    0.7895    0.7229        38
#
#     accuracy                         0.7653        98
#    macro avg     0.7579    0.7697    0.7597        98
# weighted avg     0.7783    0.7653    0.7679        98

# %% [markdown]
# # Switzerland

# %%
path_train = 'swi_metadata_rnn_train.csv'
path_test = 'swi_metadata_rnn_test.csv'
model = '../Models/Meta_Only/RNNMeta_CNN.h5'
Test(path_train,path_test,model)
# Out:
# [[ 0  0]
#  [ 3 38]]
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000         3
#            1     0.9268    1.0000    0.9620        38
#
#     accuracy                         0.9268        41
#    macro avg     0.4634    0.5000    0.4810        41
# weighted avg     0.8590    0.9268    0.8916        41
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # DNN

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

# define the model architecture
model = Sequential()
model.add(Dense(64, input_shape=(64,), activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
model.fit(X_train, Y_train_binary, epochs=1000, batch_size=32,callbacks=[callback])
Y_pred = model.predict(X_test).argmax(axis=1)
    
cm = confusion_matrix(Y_pred, Y_test_binary)
print(cm)
print(classification_report(Y_test_binary, Y_pred, digits=4))
# Out:
# Epoch 1/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6469 - accuracy: 0.6211
# Epoch 2/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5816 - accuracy: 0.7398
# Epoch 3/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5267 - accuracy: 0.7675
# Epoch 4/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4934 - accuracy: 0.7919
# Epoch 5/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4914 - accuracy: 0.7789
# Epoch 6/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4944 - accuracy: 0.7740
# Epoch 7/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4757 - accuracy: 0.7902
# Epoch 8/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4932 - accuracy: 0.7870
# Epoch 9/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4755 - accuracy: 0.7854
# Epoch 10/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4682 - accuracy: 0.7886
# Epoch 11/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4354 - accuracy: 0.8098
# Epoch 12/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4267 - accuracy: 0.8098
# Epoch 13/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4386 - accuracy: 0.8065
# Epoch 14/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4245 - accuracy: 0.8081
# Epoch 15/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4178 - accuracy: 0.8130
# Epoch 16/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3952 - accuracy: 0.8211
# Epoch 17/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4052 - accuracy: 0.8244
# Epoch 18/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.8114
# Epoch 19/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3926 - accuracy: 0.8260
# Epoch 20/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4053 - accuracy: 0.8065
# Epoch 21/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4094 - accuracy: 0.8309
# Epoch 22/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3943 - accuracy: 0.8195
# Epoch 23/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3739 - accuracy: 0.8325
# Epoch 24/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3918 - accuracy: 0.8163
# Epoch 25/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3738 - accuracy: 0.8276
# Epoch 26/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3581 - accuracy: 0.8439
# Epoch 27/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3685 - accuracy: 0.8341
# Epoch 28/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3513 - accuracy: 0.8423
# Epoch 29/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3398 - accuracy: 0.8569
# Epoch 30/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3583 - accuracy: 0.8455
# Epoch 31/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3451 - accuracy: 0.8569
# Epoch 32/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3585 - accuracy: 0.8650
# Epoch 33/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3335 - accuracy: 0.8602
# Epoch 34/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3579 - accuracy: 0.8504
# Epoch 35/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3432 - accuracy: 0.8472
# Epoch 36/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3378 - accuracy: 0.8488
# Epoch 37/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3484 - accuracy: 0.8439
# Epoch 38/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3812 - accuracy: 0.8260
# [[ 86   9]
#  [ 44 166]]
#               precision    recall  f1-score   support
#
#            0     0.9053    0.6615    0.7644       130
#            1     0.7905    0.9486    0.8623       175
#
#     accuracy                         0.8262       305
#    macro avg     0.8479    0.8051    0.8134       305
# weighted avg     0.8394    0.8262    0.8206       305

# %%
model.save('../Models/Meta_Only/RNNMeta_DNN.h5')

# %%
print("Cle test")
path_train = 'cle_metadata_rnn_train.csv'
path_test = 'cle_metadata_rnn_test.csv'
model = '../Models/Meta_Only/RNNMeta_DNN.h5'
Test(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_rnn_train.csv'
path_test = 'vir_metadata_rnn_test.csv'
model = '../Models/Meta_Only/RNNMeta_DNN.h5'
Test(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_rnn_train.csv'
path_test = 'hun_metadata_rnn_test.csv'
model = '../Models/Meta_Only/RNNMeta_DNN.h5'
Test(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_rnn_train.csv'
path_test = 'swi_metadata_rnn_test.csv'
model = '../Models/Meta_Only/RNNMeta_DNN.h5'
Test(path_train,path_test,model)
# Out:
# Cle test
# [[34  2]
#  [18 46]]
#               precision    recall  f1-score   support
#
#            0     0.9444    0.6538    0.7727        52
#            1     0.7188    0.9583    0.8214        48
#
#     accuracy                         0.8000       100
#    macro avg     0.8316    0.8061    0.7971       100
# weighted avg     0.8361    0.8000    0.7961       100
#
# ==================
# vir test
# [[ 0  0]
#  [15 51]]
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        15
#            1     0.7727    1.0000    0.8718        51
#
#     accuracy                         0.7727        66
#    macro avg     0.3864    0.5000    0.4359        66
# weighted avg     0.5971    0.7727    0.6737        66
#
# ==================
# hun test
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [[52  7]
#  [ 8 31]]
#               precision    recall  f1-score   support
#
#            0     0.8814    0.8667    0.8739        60
#            1     0.7949    0.8158    0.8052        38
#
#     accuracy                         0.8469        98
#    macro avg     0.8381    0.8412    0.8396        98
# weighted avg     0.8478    0.8469    0.8473        98
#
# ==================
# swi test
# [[ 0  0]
#  [ 3 38]]
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000         3
#            1     0.9268    1.0000    0.9620        38
#
#     accuracy                         0.9268        41
#    macro avg     0.4634    0.5000    0.4810        41
# weighted avg     0.8590    0.9268    0.8916        41
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # RNN

# %%
from keras.layers import Dense, SimpleRNN

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

# define the model architecture
model = Sequential()
model.add(SimpleRNN(units=64, return_sequences=True, input_shape=(64, 1)))
model.add(SimpleRNN(units=32, return_sequences=True))
model.add(SimpleRNN(units=16))
model.add(Dense(units=2, activation='sigmoid'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
model.fit(X_train, Y_train_binary, epochs=1000, batch_size=32,callbacks=[callback])
Y_pred = model.predict(X_test).argmax(axis=1)
    
cm = confusion_matrix(Y_pred, Y_test_binary)
print(cm)
print(classification_report(Y_test_binary, Y_pred, digits=4))
# Out:
# Epoch 1/1000
# 20/20 [==============================] - 3s 38ms/step - loss: 0.6614 - accuracy: 0.6016
# Epoch 2/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5473 - accuracy: 0.7496
# Epoch 3/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5657 - accuracy: 0.7268
# Epoch 4/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.4823 - accuracy: 0.7902
# Epoch 5/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.4697 - accuracy: 0.7967
# Epoch 6/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.4627 - accuracy: 0.7870
# Epoch 7/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.4600 - accuracy: 0.7870
# Epoch 8/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.4389 - accuracy: 0.8081
# Epoch 9/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.4186 - accuracy: 0.8211
# Epoch 10/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.4243 - accuracy: 0.8228
# Epoch 11/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.4057 - accuracy: 0.8065
# Epoch 12/1000
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4120 - accuracy: 0.8130
# Epoch 13/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.4029 - accuracy: 0.8390
# Epoch 14/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.3910 - accuracy: 0.8130
# Epoch 15/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.3862 - accuracy: 0.8244
# Epoch 16/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.4109 - accuracy: 0.8130
# Epoch 17/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.3953 - accuracy: 0.8325
# Epoch 18/1000
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3826 - accuracy: 0.8293
# Epoch 19/1000
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3982 - accuracy: 0.8293
# Epoch 20/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.3905 - accuracy: 0.8488
# Epoch 21/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.3730 - accuracy: 0.8325
# Epoch 22/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.3764 - accuracy: 0.8325
# Epoch 23/1000
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3673 - accuracy: 0.8423
# Epoch 24/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.3558 - accuracy: 0.8569
# Epoch 25/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.3465 - accuracy: 0.8488
# Epoch 26/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.3554 - accuracy: 0.8488
# Epoch 27/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.3220 - accuracy: 0.8764
# Epoch 28/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.3430 - accuracy: 0.8602
# Epoch 29/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.3431 - accuracy: 0.8520
# Epoch 30/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.3460 - accuracy: 0.8553
# Epoch 31/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.3340 - accuracy: 0.8569
# Epoch 32/1000
# 20/20 [==============================] - 1s 41ms/step - loss: 0.3523 - accuracy: 0.8553
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FF2F14C280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[ 81   6]
#  [ 49 169]]
#               precision    recall  f1-score   support
#
#            0     0.9310    0.6231    0.7465       130
#            1     0.7752    0.9657    0.8601       175
#
#     accuracy                         0.8197       305
#    macro avg     0.8531    0.7944    0.8033       305
# weighted avg     0.8416    0.8197    0.8117       305

# %%
model.save('../Models/Meta_Only/RNNMeta_RNN.h5')

# %%
print("Cle test")
path_train = 'cle_metadata_rnn_train.csv'
path_test = 'cle_metadata_rnn_test.csv'
model = '../Models/Meta_Only/RNNMeta_RNN.h5'
Test(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_rnn_train.csv'
path_test = 'vir_metadata_rnn_test.csv'
model = '../Models/Meta_Only/RNNMeta_RNN.h5'
Test(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_rnn_train.csv'
path_test = 'hun_metadata_rnn_test.csv'
model = '../Models/Meta_Only/RNNMeta_RNN.h5'
Test(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_rnn_train.csv'
path_test = 'swi_metadata_rnn_test.csv'
model = '../Models/Meta_Only/RNNMeta_RNN.h5'
Test(path_train,path_test,model)
# Out:
# Cle test
# [[32  2]
#  [20 46]]
#               precision    recall  f1-score   support
#
#            0     0.9412    0.6154    0.7442        52
#            1     0.6970    0.9583    0.8070        48
#
#     accuracy                         0.7800       100
#    macro avg     0.8191    0.7869    0.7756       100
# weighted avg     0.8240    0.7800    0.7743       100
#
# ==================
# vir test
# [[ 3  1]
#  [12 50]]
#               precision    recall  f1-score   support
#
#            0     0.7500    0.2000    0.3158        15
#            1     0.8065    0.9804    0.8850        51
#
#     accuracy                         0.8030        66
#    macro avg     0.7782    0.5902    0.6004        66
# weighted avg     0.7936    0.8030    0.7556        66
#
# ==================
# hun test
# [[46  3]
#  [14 35]]
#               precision    recall  f1-score   support
#
#            0     0.9388    0.7667    0.8440        60
#            1     0.7143    0.9211    0.8046        38
#
#     accuracy                         0.8265        98
#    macro avg     0.8265    0.8439    0.8243        98
# weighted avg     0.8517    0.8265    0.8287        98
#
# ==================
# swi test
# [[ 0  0]
#  [ 3 38]]
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000         3
#            1     0.9268    1.0000    0.9620        38
#
#     accuracy                         0.9268        41
#    macro avg     0.4634    0.5000    0.4810        41
# weighted avg     0.8590    0.9268    0.8916        41
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Machine Learning

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy')
clf.fit(X_train, Y_train_binary)
Y_predictions = clf.predict(X_test)
cm = confusion_matrix(Y_predictions, Y_test_binary)
print("Confusion Matrix is:")
print(cm)
def accuracy(confusion_matrix):
    diagonal_sum = confusion_matrix.trace()
    sum_of_all_elements = confusion_matrix.sum()
    return diagonal_sum / sum_of_all_elements
print("Accuracy is : " + str(accuracy(cm)))

print("Report")
print(classification_report(Y_test_binary, Y_predictions))

#Visualization of the tree
plt.figure(figsize=(25,20))
tree.plot_tree(clf, filled=True, fontsize=10, max_depth= None,feature_names = list(X_train.columns), class_names = True)
plt.show()
# Out:
# Confusion Matrix is:
# [[ 96  32]
#  [ 34 143]]
# Accuracy is : 0.7836065573770492
# Report
#               precision    recall  f1-score   support
#
#            0       0.75      0.74      0.74       130
#            1       0.81      0.82      0.81       175
#
#     accuracy                           0.78       305
#    macro avg       0.78      0.78      0.78       305
# weighted avg       0.78      0.78      0.78       305

# %%
from joblib import dump, load
dump(clf, '../Models/Meta_only/RNNMeta_clf.joblib')
# Out:
# ['../Models/Meta_only/RNNMeta_clf.joblib']

# %%
def Test(path_train,path_test,model_name):
    Train = pd.read_csv(path_train)
    Test = pd.read_csv(path_test)

    X_train = Train.iloc[:,:-1]
    Y_train = Train.iloc[:,-1]

    X_test = Test.iloc[:,:-1]
    Y_test = Test.iloc[:,-1]

    #binarize the target
    Y_train_binary = Y_train.apply(lambda x: 1 if x > 0 else 0)
    Y_test_binary = Y_test.apply(lambda x: 1 if x > 0 else 0)

    model = load(model_name)

    Y_pred = model.predict(X_test)

    cm = confusion_matrix(Y_pred, Y_test_binary)
    print(cm)
    print(classification_report(Y_test_binary, Y_pred, digits=4))

# %%
print("Cle test")
path_train = 'cle_metadata_rnn_train.csv'
path_test = 'cle_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_clf.joblib'
Test(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_rnn_train.csv'
path_test = 'vir_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_clf.joblib'
Test(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_rnn_train.csv'
path_test = 'hun_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_clf.joblib'
Test(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_rnn_train.csv'
path_test = 'swi_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_clf.joblib'
Test(path_train,path_test,model)
# Out:
# Cle test
# [[38  6]
#  [14 42]]
#               precision    recall  f1-score   support
#
#            0     0.8636    0.7308    0.7917        52
#            1     0.7500    0.8750    0.8077        48
#
#     accuracy                         0.8000       100
#    macro avg     0.8068    0.8029    0.7997       100
# weighted avg     0.8091    0.8000    0.7994       100
#
# ==================
# vir test
# [[11 12]
#  [ 4 39]]
#               precision    recall  f1-score   support
#
#            0     0.4783    0.7333    0.5789        15
#            1     0.9070    0.7647    0.8298        51
#
#     accuracy                         0.7576        66
#    macro avg     0.6926    0.7490    0.7044        66
# weighted avg     0.8095    0.7576    0.7728        66
#
# ==================
# hun test
# [[46 10]
#  [14 28]]
#               precision    recall  f1-score   support
#
#            0     0.8214    0.7667    0.7931        60
#            1     0.6667    0.7368    0.7000        38
#
#     accuracy                         0.7551        98
#    macro avg     0.7440    0.7518    0.7466        98
# weighted avg     0.7614    0.7551    0.7570        98
#
# ==================
# swi test
# [[ 1  4]
#  [ 2 34]]
#               precision    recall  f1-score   support
#
#            0     0.2000    0.3333    0.2500         3
#            1     0.9444    0.8947    0.9189        38
#
#     accuracy                         0.8537        41
#    macro avg     0.5722    0.6140    0.5845        41
# weighted avg     0.8900    0.8537    0.8700        41

# %% [markdown]
# # Bayesian Classifier

# %%
from sklearn.naive_bayes import GaussianNB

classifier = GaussianNB()
classifier.fit(X_train, Y_train_binary)
Y_pred = classifier.predict(X_test)
cm = confusion_matrix(Y_pred, Y_test_binary)
print(cm)
print(classification_report(Y_test_binary, Y_pred))
# Out:
# [[ 97  45]
#  [ 33 130]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.75      0.71       130
#            1       0.80      0.74      0.77       175
#
#     accuracy                           0.74       305
#    macro avg       0.74      0.74      0.74       305
# weighted avg       0.75      0.74      0.75       305

# %%
dump(clf, '../Models/Meta_only/RNNMeta_NB.joblib')
# Out:
# ['../Models/Meta_only/RNNMeta_NB.joblib']

# %%
print("Cle test")
path_train = 'cle_metadata_rnn_train.csv'
path_test = 'cle_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_NB.joblib'
Test(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_rnn_train.csv'
path_test = 'vir_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_NB.joblib'
Test(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_rnn_train.csv'
path_test = 'hun_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_NB.joblib'
Test(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_rnn_train.csv'
path_test = 'swi_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_NB.joblib'
Test(path_train,path_test,model)
# Out:
# Cle test
# [[38  6]
#  [14 42]]
#               precision    recall  f1-score   support
#
#            0     0.8636    0.7308    0.7917        52
#            1     0.7500    0.8750    0.8077        48
#
#     accuracy                         0.8000       100
#    macro avg     0.8068    0.8029    0.7997       100
# weighted avg     0.8091    0.8000    0.7994       100
#
# ==================
# vir test
# [[11 12]
#  [ 4 39]]
#               precision    recall  f1-score   support
#
#            0     0.4783    0.7333    0.5789        15
#            1     0.9070    0.7647    0.8298        51
#
#     accuracy                         0.7576        66
#    macro avg     0.6926    0.7490    0.7044        66
# weighted avg     0.8095    0.7576    0.7728        66
#
# ==================
# hun test
# [[46 10]
#  [14 28]]
#               precision    recall  f1-score   support
#
#            0     0.8214    0.7667    0.7931        60
#            1     0.6667    0.7368    0.7000        38
#
#     accuracy                         0.7551        98
#    macro avg     0.7440    0.7518    0.7466        98
# weighted avg     0.7614    0.7551    0.7570        98
#
# ==================
# swi test
# [[ 1  4]
#  [ 2 34]]
#               precision    recall  f1-score   support
#
#            0     0.2000    0.3333    0.2500         3
#            1     0.9444    0.8947    0.9189        38
#
#     accuracy                         0.8537        41
#    macro avg     0.5722    0.6140    0.5845        41
# weighted avg     0.8900    0.8537    0.8700        41

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators=100, random_state=42)
classifier.fit(X_train, Y_train_binary)
Y_pred = classifier.predict(X_test)
cm = confusion_matrix(Y_pred, Y_test_binary)
print(cm)
print(classification_report(Y_test_binary, Y_pred))
# Out:
# [[ 97  16]
#  [ 33 159]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80       130
#            1       0.83      0.91      0.87       175
#
#     accuracy                           0.84       305
#    macro avg       0.84      0.83      0.83       305
# weighted avg       0.84      0.84      0.84       305

# %%
dump(classifier, '../Models/Meta_only/RNNMeta_RF.joblib')
# Out:
# ['../Models/Meta_only/RNNMeta_RF.joblib']

# %%
print("Cle test")
path_train = 'cle_metadata_rnn_train.csv'
path_test = 'cle_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_RF.joblib'
Test(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_rnn_train.csv'
path_test = 'vir_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_RF.joblib'
Test(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_rnn_train.csv'
path_test = 'hun_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_RF.joblib'
Test(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_rnn_train.csv'
path_test = 'swi_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_RF.joblib'
Test(path_train,path_test,model)
# Out:
# Cle test
# [[38  2]
#  [14 46]]
#               precision    recall  f1-score   support
#
#            0     0.9500    0.7308    0.8261        52
#            1     0.7667    0.9583    0.8519        48
#
#     accuracy                         0.8400       100
#    macro avg     0.8583    0.8446    0.8390       100
# weighted avg     0.8620    0.8400    0.8385       100
#
# ==================
# vir test
# [[ 3  4]
#  [12 47]]
#               precision    recall  f1-score   support
#
#            0     0.4286    0.2000    0.2727        15
#            1     0.7966    0.9216    0.8545        51
#
#     accuracy                         0.7576        66
#    macro avg     0.6126    0.5608    0.5636        66
# weighted avg     0.7130    0.7576    0.7223        66
#
# ==================
# hun test
# [[56 10]
#  [ 4 28]]
#               precision    recall  f1-score   support
#
#            0     0.8485    0.9333    0.8889        60
#            1     0.8750    0.7368    0.8000        38
#
#     accuracy                         0.8571        98
#    macro avg     0.8617    0.8351    0.8444        98
# weighted avg     0.8588    0.8571    0.8544        98
#
# ==================
# swi test
# [[ 0  0]
#  [ 3 38]]
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000         3
#            1     0.9268    1.0000    0.9620        38
#
#     accuracy                         0.9268        41
#    macro avg     0.4634    0.5000    0.4810        41
# weighted avg     0.8590    0.9268    0.8916        41
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(X_train, Y_train_binary.values.ravel())
y_pred = svc.predict(X_test)
print(confusion_matrix(Y_test_binary, y_pred))
print(classification_report(Y_test_binary, y_pred))
# Out:
# [[ 97  33]
#  [ 16 159]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80       130
#            1       0.83      0.91      0.87       175
#
#     accuracy                           0.84       305
#    macro avg       0.84      0.83      0.83       305
# weighted avg       0.84      0.84      0.84       305

# %%
dump(svc, '../Models/Meta_only/RNNMeta_SVM.joblib')
# Out:
# ['../Models/Meta_only/RNNMeta_SVM.joblib']

# %%
print("Cle test")
path_train = 'cle_metadata_rnn_train.csv'
path_test = 'cle_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_SVM.joblib'
Test(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_rnn_train.csv'
path_test = 'vir_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_SVM.joblib'
Test(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_rnn_train.csv'
path_test = 'hun_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_SVM.joblib'
Test(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_rnn_train.csv'
path_test = 'swi_metadata_rnn_test.csv'
model = '../Models/Meta_only/RNNMeta_SVM.joblib'
Test(path_train,path_test,model)
# Out:
# Cle test
# [[39  5]
#  [13 43]]
#               precision    recall  f1-score   support
#
#            0     0.8864    0.7500    0.8125        52
#            1     0.7679    0.8958    0.8269        48
#
#     accuracy                         0.8200       100
#    macro avg     0.8271    0.8229    0.8197       100
# weighted avg     0.8295    0.8200    0.8194       100
#
# ==================
# vir test
# [[ 2  0]
#  [13 51]]
#               precision    recall  f1-score   support
#
#            0     1.0000    0.1333    0.2353        15
#            1     0.7969    1.0000    0.8870        51
#
#     accuracy                         0.8030        66
#    macro avg     0.8984    0.5667    0.5611        66
# weighted avg     0.8430    0.8030    0.7389        66
#
# ==================
# hun test
# [[56 11]
#  [ 4 27]]
#               precision    recall  f1-score   support
#
#            0     0.8358    0.9333    0.8819        60
#            1     0.8710    0.7105    0.7826        38
#
#     accuracy                         0.8469        98
#    macro avg     0.8534    0.8219    0.8322        98
# weighted avg     0.8494    0.8469    0.8434        98
#
# ==================
# swi test
# [[ 0  0]
#  [ 3 38]]
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000         3
#            1     0.9268    1.0000    0.9620        38
#
#     accuracy                         0.9268        41
#    macro avg     0.4634    0.5000    0.4810        41
# weighted avg     0.8590    0.9268    0.8916        41
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
