# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %% [markdown]
# # CNN metadata:

# %%
cle = pd.read_csv('cle_metadata_cnn.csv')
vir = pd.read_csv('vir_metadata_cnn.csv')
hun = pd.read_csv('hun_metadata_cnn.csv')
swi = pd.read_csv('swi_metadata_cnn.csv')

# %%
cle_train,cle_test = train_test_split(cle,test_size=0.33, random_state=42)
vir_train,vir_test = train_test_split(vir,test_size=0.33, random_state=42)
hun_train,hun_test = train_test_split(hun,test_size=0.33, random_state=42)
swi_train,swi_test = train_test_split(swi,test_size=0.33, random_state=42)

# %%
cle_train.to_csv('cle_metadata_cnn_train.csv',index = False)
cle_test.to_csv('cle_metadata_cnn_test.csv',index = False)

# %%
vir_train.to_csv('vir_metadata_cnn_train.csv',index = False)
vir_test.to_csv('vir_metadata_cnn_test.csv',index = False)

# %%
hun_train.to_csv('hun_metadata_cnn_train.csv',index = False)
hun_test.to_csv('hun_metadata_cnn_test.csv',index = False)

# %%
swi_train.to_csv('swi_metadata_cnn_train.csv',index = False)
swi_test.to_csv('swi_metadata_cnn_test.csv',index = False)

# %%
Train = pd.concat([cle_train,vir_train,hun_train,swi_train])
Test = pd.concat([cle_test,vir_test,hun_test,swi_test])

# %%
X_train = Train.iloc[:,:-1]
X_test = Test.iloc[:,:-1]

y_train = Train.iloc[:,-1]
y_test = Test.iloc[:,-1]

Y_train_binary = y_train.apply(lambda x: 1 if x > 0 else 0)
Y_test_binary = y_test.apply(lambda x: 1 if x > 0 else 0)

# %%
# function for deep learning testing
def Test(path_train,path_test,model_name):
    Train = pd.read_csv(path_train)
    Test = pd.read_csv(path_test)
    
    X_train = Train.iloc[:,:-1]
    Y_train = Train.iloc[:,-1]

    X_test = Test.iloc[:,:-1]
    Y_test = Test.iloc[:,-1]

    #binarize the target
    Y_train_binary = Y_train.apply(lambda x: 1 if x > 0 else 0)
    Y_test_binary = Y_test.apply(lambda x: 1 if x > 0 else 0)

    model = tf.keras.models.load_model(model_name)

    Y_pred = model.predict(X_test).argmax(axis=1)
    
    cm = confusion_matrix(Y_pred, Y_test_binary)
    print(cm)
    print(classification_report(Y_test_binary, Y_pred, digits=4))

# %% [markdown]
# # CNN

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

# define the model architecture
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(64,1)))
model.add(Conv1D(filters=256, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

model.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
model.fit(X_train, Y_train_binary, epochs=1000, batch_size=32,callbacks=[callback])
Y_pred = model.predict(X_test).argmax(axis=1)
    
cm = confusion_matrix(Y_pred, Y_test_binary)
print(cm)
print(classification_report(Y_test_binary, Y_pred, digits=4))
# Out:
# Epoch 1/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5336 - accuracy: 0.7691
# Epoch 2/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.4313 - accuracy: 0.8423
# Epoch 3/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.3852 - accuracy: 0.8504
# Epoch 4/1000
# 20/20 [==============================] - 1s 37ms/step - loss: 0.3723 - accuracy: 0.8618
# Epoch 5/1000
# 20/20 [==============================] - 1s 40ms/step - loss: 0.3406 - accuracy: 0.8715
# Epoch 6/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.3377 - accuracy: 0.8780
# Epoch 7/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.3453 - accuracy: 0.8699
# Epoch 8/1000
# 20/20 [==============================] - 1s 37ms/step - loss: 0.3370 - accuracy: 0.8683
# Epoch 9/1000
# 20/20 [==============================] - 1s 40ms/step - loss: 0.3346 - accuracy: 0.8797
# Epoch 10/1000
# 20/20 [==============================] - 1s 40ms/step - loss: 0.3255 - accuracy: 0.8699
# Epoch 11/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.3241 - accuracy: 0.8813
# Epoch 12/1000
# 20/20 [==============================] - 1s 37ms/step - loss: 0.3301 - accuracy: 0.8748
# Epoch 13/1000
# 20/20 [==============================] - 1s 37ms/step - loss: 0.3238 - accuracy: 0.8797
# Epoch 14/1000
# 20/20 [==============================] - 1s 40ms/step - loss: 0.3150 - accuracy: 0.8894
# Epoch 15/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.3161 - accuracy: 0.8878
# Epoch 16/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.3177 - accuracy: 0.8846
# Epoch 17/1000
# 20/20 [==============================] - 1s 37ms/step - loss: 0.3240 - accuracy: 0.8667
# Epoch 18/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.3108 - accuracy: 0.8894
# Epoch 19/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.3126 - accuracy: 0.8862
# Epoch 20/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.3187 - accuracy: 0.8829
# Epoch 21/1000
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3655 - accuracy: 0.8602
# Epoch 22/1000
# 20/20 [==============================] - 1s 40ms/step - loss: 0.3366 - accuracy: 0.8780
# Epoch 23/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.3097 - accuracy: 0.8927
# Epoch 24/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.3037 - accuracy: 0.8894
# Epoch 25/1000
# 20/20 [==============================] - 1s 37ms/step - loss: 0.3106 - accuracy: 0.8764
# Epoch 26/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.3039 - accuracy: 0.8894
# Epoch 27/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.3061 - accuracy: 0.8894
# Epoch 28/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.3017 - accuracy: 0.8862
# Epoch 29/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.3031 - accuracy: 0.8878
# Epoch 30/1000
# 20/20 [==============================] - 1s 37ms/step - loss: 0.2994 - accuracy: 0.8927
# Epoch 31/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.2902 - accuracy: 0.8959
# Epoch 32/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.3083 - accuracy: 0.8894
# Epoch 33/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.2920 - accuracy: 0.8959
# Epoch 34/1000
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3136 - accuracy: 0.8797
# Epoch 35/1000
# 20/20 [==============================] - 1s 40ms/step - loss: 0.2866 - accuracy: 0.8927
# Epoch 36/1000
# 20/20 [==============================] - 1s 40ms/step - loss: 0.2993 - accuracy: 0.8911
# Epoch 37/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.2982 - accuracy: 0.8813
# Epoch 38/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.2994 - accuracy: 0.8927
# Epoch 39/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.3049 - accuracy: 0.8862
# Epoch 40/1000
# 20/20 [==============================] - 1s 39ms/step - loss: 0.2898 - accuracy: 0.8976
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001ADF38094C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 10/10 [==============================] - 0s 9ms/step
# [[ 91   9]
#  [ 39 166]]
#               precision    recall  f1-score   support
#
#            0     0.9100    0.7000    0.7913       130
#            1     0.8098    0.9486    0.8737       175
#
#     accuracy                         0.8426       305
#    macro avg     0.8599    0.8243    0.8325       305
# weighted avg     0.8525    0.8426    0.8386       305

# %%
model.save('../Models/Meta_Only/CNNMeta_CNN.h5')

# %% [markdown]
# # Test on each dataset

# %%
print("Cle test")
path_train = 'cle_metadata_cnn_train.csv'
path_test = 'cle_metadata_cnn_test.csv'
model = '../Models/Meta_Only/CNNMeta_CNN.h5'
Test(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_cnn_train.csv'
path_test = 'vir_metadata_cnn_test.csv'
model = '../Models/Meta_Only/CNNMeta_CNN.h5'
Test(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_cnn_train.csv'
path_test = 'hun_metadata_cnn_test.csv'
model = '../Models/Meta_Only/CNNMeta_CNN.h5'
Test(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_cnn_train.csv'
path_test = 'swi_metadata_cnn_test.csv'
model = '../Models/Meta_Only/CNNMeta_CNN.h5'
Test(path_train,path_test,model)
# Out:
# Cle test
# 4/4 [==============================] - 0s 7ms/step
# [[38  4]
#  [14 44]]
#               precision    recall  f1-score   support
#
#            0     0.9048    0.7308    0.8085        52
#            1     0.7586    0.9167    0.8302        48
#
#     accuracy                         0.8200       100
#    macro avg     0.8317    0.8237    0.8193       100
# weighted avg     0.8346    0.8200    0.8189       100
#
# ==================
# vir test
# 3/3 [==============================] - 0s 6ms/step
# [[ 4  1]
#  [11 50]]
#               precision    recall  f1-score   support
#
#            0     0.8000    0.2667    0.4000        15
#            1     0.8197    0.9804    0.8929        51
#
#     accuracy                         0.8182        66
#    macro avg     0.8098    0.6235    0.6464        66
# weighted avg     0.8152    0.8182    0.7808        66
#
# ==================
# hun test
# 4/4 [==============================] - 0s 7ms/step
# [[48  2]
#  [12 36]]
#               precision    recall  f1-score   support
#
#            0     0.9600    0.8000    0.8727        60
#            1     0.7500    0.9474    0.8372        38
#
#     accuracy                         0.8571        98
#    macro avg     0.8550    0.8737    0.8550        98
# weighted avg     0.8786    0.8571    0.8590        98
#
# ==================
# swi test
# 2/2 [==============================] - 0s 6ms/step
# [[ 1  2]
#  [ 2 36]]
#               precision    recall  f1-score   support
#
#            0     0.3333    0.3333    0.3333         3
#            1     0.9474    0.9474    0.9474        38
#
#     accuracy                         0.9024        41
#    macro avg     0.6404    0.6404    0.6404        41
# weighted avg     0.9024    0.9024    0.9024        41

# %% [markdown]
# # DNN

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

# define the model architecture
model = Sequential()
model.add(Dense(64, input_shape=(64,), activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
model.fit(X_train, Y_train_binary, epochs=1000, batch_size=32,callbacks=[callback])
Y_pred = model.predict(X_test).argmax(axis=1)
    
cm = confusion_matrix(Y_pred, Y_test_binary)
print(cm)
print(classification_report(Y_test_binary, Y_pred, digits=4))
# Out:
# Epoch 1/1000
# 20/20 [==============================] - 0s 895us/step - loss: 0.5343 - accuracy: 0.7447
# Epoch 2/1000
# 20/20 [==============================] - 0s 842us/step - loss: 0.3939 - accuracy: 0.8374
# Epoch 3/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3579 - accuracy: 0.8553
# Epoch 4/1000
# 20/20 [==============================] - 0s 842us/step - loss: 0.3619 - accuracy: 0.8602
# Epoch 5/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3570 - accuracy: 0.8520
# Epoch 6/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3525 - accuracy: 0.8569
# Epoch 7/1000
# 20/20 [==============================] - 0s 790us/step - loss: 0.3502 - accuracy: 0.8650
# Epoch 8/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3489 - accuracy: 0.8650
# Epoch 9/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3611 - accuracy: 0.8585
# Epoch 10/1000
# 20/20 [==============================] - 0s 842us/step - loss: 0.3403 - accuracy: 0.8650
# Epoch 11/1000
# 20/20 [==============================] - 0s 842us/step - loss: 0.3458 - accuracy: 0.8618
# Epoch 12/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3475 - accuracy: 0.8683
# Epoch 13/1000
# 20/20 [==============================] - 0s 895us/step - loss: 0.3346 - accuracy: 0.8732
# Epoch 14/1000
# 20/20 [==============================] - 0s 842us/step - loss: 0.3316 - accuracy: 0.8780
# Epoch 15/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3294 - accuracy: 0.8683
# Epoch 16/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3399 - accuracy: 0.8699
# Epoch 17/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3291 - accuracy: 0.8748
# Epoch 18/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3297 - accuracy: 0.8764
# Epoch 19/1000
# 20/20 [==============================] - 0s 790us/step - loss: 0.3344 - accuracy: 0.8797
# Epoch 20/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3231 - accuracy: 0.8797
# Epoch 21/1000
# 20/20 [==============================] - 0s 842us/step - loss: 0.3264 - accuracy: 0.8813
# Epoch 22/1000
# 20/20 [==============================] - 0s 790us/step - loss: 0.3200 - accuracy: 0.8780
# Epoch 23/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3239 - accuracy: 0.8732
# Epoch 24/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3261 - accuracy: 0.8764
# Epoch 25/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3240 - accuracy: 0.8829
# Epoch 26/1000
# 20/20 [==============================] - 0s 790us/step - loss: 0.3206 - accuracy: 0.8813
# Epoch 27/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3146 - accuracy: 0.8862
# Epoch 28/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3377 - accuracy: 0.8732
# Epoch 29/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3188 - accuracy: 0.8829
# Epoch 30/1000
# 20/20 [==============================] - 0s 842us/step - loss: 0.3210 - accuracy: 0.8927
# Epoch 31/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3248 - accuracy: 0.8797
# Epoch 32/1000
# 20/20 [==============================] - 0s 789us/step - loss: 0.3176 - accuracy: 0.8748
# 10/10 [==============================] - 0s 556us/step
# [[ 91  10]
#  [ 39 165]]
#               precision    recall  f1-score   support
#
#            0     0.9010    0.7000    0.7879       130
#            1     0.8088    0.9429    0.8707       175
#
#     accuracy                         0.8393       305
#    macro avg     0.8549    0.8214    0.8293       305
# weighted avg     0.8481    0.8393    0.8354       305

# %%
model.save('../Models/Meta_Only/CNNMeta_DNN.h5')

# %% [markdown]
# # test on each dataset

# %%
print("Cle test")
path_train = 'cle_metadata_cnn_train.csv'
path_test = 'cle_metadata_cnn_test.csv'
model = '../Models/Meta_Only/CNNMeta_DNN.h5'
Test(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_cnn_train.csv'
path_test = 'vir_metadata_cnn_test.csv'
model = '../Models/Meta_Only/CNNMeta_DNN.h5'
Test(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_cnn_train.csv'
path_test = 'hun_metadata_cnn_test.csv'
model = '../Models/Meta_Only/CNNMeta_DNN.h5'
Test(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_cnn_train.csv'
path_test = 'swi_metadata_cnn_test.csv'
model = '../Models/Meta_Only/CNNMeta_DNN.h5'
Test(path_train,path_test,model)
# Out:
# Cle test
# 4/4 [==============================] - 0s 633us/step
# [[37  5]
#  [15 43]]
#               precision    recall  f1-score   support
#
#            0     0.8810    0.7115    0.7872        52
#            1     0.7414    0.8958    0.8113        48
#
#     accuracy                         0.8000       100
#    macro avg     0.8112    0.8037    0.7993       100
# weighted avg     0.8140    0.8000    0.7988       100
#
# ==================
# vir test
# 3/3 [==============================] - 0s 999us/step
# [[ 4  0]
#  [11 51]]
#               precision    recall  f1-score   support
#
#            0     1.0000    0.2667    0.4211        15
#            1     0.8226    1.0000    0.9027        51
#
#     accuracy                         0.8333        66
#    macro avg     0.9113    0.6333    0.6619        66
# weighted avg     0.8629    0.8333    0.7932        66
#
# ==================
# hun test
# 4/4 [==============================] - 0s 667us/step
# [[49  3]
#  [11 35]]
#               precision    recall  f1-score   support
#
#            0     0.9423    0.8167    0.8750        60
#            1     0.7609    0.9211    0.8333        38
#
#     accuracy                         0.8571        98
#    macro avg     0.8516    0.8689    0.8542        98
# weighted avg     0.8720    0.8571    0.8588        98
#
# ==================
# swi test
# 2/2 [==============================] - 0s 2ms/step
# [[ 1  2]
#  [ 2 36]]
#               precision    recall  f1-score   support
#
#            0     0.3333    0.3333    0.3333         3
#            1     0.9474    0.9474    0.9474        38
#
#     accuracy                         0.9024        41
#    macro avg     0.6404    0.6404    0.6404        41
# weighted avg     0.9024    0.9024    0.9024        41

# %% [markdown]
# # RNN

# %%
from keras.layers import Dense, SimpleRNN

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

# define the model architecture
model = Sequential()
model.add(SimpleRNN(units=64, return_sequences=True, input_shape=(64, 1)))
model.add(SimpleRNN(units=32, return_sequences=True))
model.add(SimpleRNN(units=16))
model.add(Dense(units=2, activation='sigmoid'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
model.fit(X_train, Y_train_binary, epochs=1000, batch_size=32,callbacks=[callback])
Y_pred = model.predict(X_test).argmax(axis=1)
    
cm = confusion_matrix(Y_pred, Y_test_binary)
print(cm)
print(classification_report(Y_test_binary, Y_pred, digits=4))
# Out:
# Epoch 1/1000
# 20/20 [==============================] - 1s 10ms/step - loss: 0.4745 - accuracy: 0.7951
# Epoch 2/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.4149 - accuracy: 0.8179
# Epoch 3/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3942 - accuracy: 0.8423
# Epoch 4/1000
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3640 - accuracy: 0.8650
# Epoch 5/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3660 - accuracy: 0.8699
# Epoch 6/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3711 - accuracy: 0.8602
# Epoch 7/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3607 - accuracy: 0.8667
# Epoch 8/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3558 - accuracy: 0.8585
# Epoch 9/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3457 - accuracy: 0.8732
# Epoch 10/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3588 - accuracy: 0.8455
# Epoch 11/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3470 - accuracy: 0.8699
# Epoch 12/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3426 - accuracy: 0.8699
# Epoch 13/1000
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3461 - accuracy: 0.8618
# Epoch 14/1000
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3408 - accuracy: 0.8748
# Epoch 15/1000
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3391 - accuracy: 0.8764
# Epoch 16/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3709 - accuracy: 0.8504
# Epoch 17/1000
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3415 - accuracy: 0.8699
# Epoch 18/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3554 - accuracy: 0.8683
# Epoch 19/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3730 - accuracy: 0.8569
# Epoch 20/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3449 - accuracy: 0.8699
# 10/10 [==============================] - 0s 3ms/step
# [[ 93  13]
#  [ 37 162]]
#               precision    recall  f1-score   support
#
#            0     0.8774    0.7154    0.7881       130
#            1     0.8141    0.9257    0.8663       175
#
#     accuracy                         0.8361       305
#    macro avg     0.8457    0.8205    0.8272       305
# weighted avg     0.8410    0.8361    0.8330       305

# %%
model.save('../Models/Meta_Only/CNNMeta_RNN.h5')

# %%
print("Cle test")
path_train = 'cle_metadata_cnn_train.csv'
path_test = 'cle_metadata_cnn_test.csv'
model = '../Models/Meta_Only/CNNMeta_RNN.h5'
Test(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_cnn_train.csv'
path_test = 'vir_metadata_cnn_test.csv'
model = '../Models/Meta_Only/CNNMeta_RNN.h5'
Test(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_cnn_train.csv'
path_test = 'hun_metadata_cnn_test.csv'
model = '../Models/Meta_Only/CNNMeta_RNN.h5'
Test(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_cnn_train.csv'
path_test = 'swi_metadata_cnn_test.csv'
model = '../Models/Meta_Only/CNNMeta_RNN.h5'
Test(path_train,path_test,model)
# Out:
# Cle test
# 4/4 [==============================] - 0s 3ms/step
# [[39  5]
#  [13 43]]
#               precision    recall  f1-score   support
#
#            0     0.8864    0.7500    0.8125        52
#            1     0.7679    0.8958    0.8269        48
#
#     accuracy                         0.8200       100
#    macro avg     0.8271    0.8229    0.8197       100
# weighted avg     0.8295    0.8200    0.8194       100
#
# ==================
# vir test
# 3/3 [==============================] - 0s 3ms/step
# [[ 4  2]
#  [11 49]]
#               precision    recall  f1-score   support
#
#            0     0.6667    0.2667    0.3810        15
#            1     0.8167    0.9608    0.8829        51
#
#     accuracy                         0.8030        66
#    macro avg     0.7417    0.6137    0.6319        66
# weighted avg     0.7826    0.8030    0.7688        66
#
# ==================
# hun test
# 4/4 [==============================] - 0s 3ms/step
# [[49  3]
#  [11 35]]
#               precision    recall  f1-score   support
#
#            0     0.9423    0.8167    0.8750        60
#            1     0.7609    0.9211    0.8333        38
#
#     accuracy                         0.8571        98
#    macro avg     0.8516    0.8689    0.8542        98
# weighted avg     0.8720    0.8571    0.8588        98
#
# ==================
# swi test
# 2/2 [==============================] - 0s 5ms/step
# [[ 1  3]
#  [ 2 35]]
#               precision    recall  f1-score   support
#
#            0     0.2500    0.3333    0.2857         3
#            1     0.9459    0.9211    0.9333        38
#
#     accuracy                         0.8780        41
#    macro avg     0.5980    0.6272    0.6095        41
# weighted avg     0.8950    0.8780    0.8859        41

# %% [markdown]
# # Machine Learning

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %%
# decision tree
clf = tree.DecisionTreeClassifier(criterion='entropy')
clf.fit(X_train, Y_train_binary)
Y_predictions = clf.predict(X_test)
cm = confusion_matrix(Y_predictions, Y_test_binary)
print("Confusion Matrix is:")
print(cm)
def accuracy(confusion_matrix):
    diagonal_sum = confusion_matrix.trace()
    sum_of_all_elements = confusion_matrix.sum()
    return diagonal_sum / sum_of_all_elements
print("Accuracy is : " + str(accuracy(cm)))
    
print("Report")
print(classification_report(Y_test_binary, Y_predictions))
    
#Visualization of the tree
plt.figure(figsize=(25,20))
tree.plot_tree(clf, filled=True, fontsize=10, max_depth= None,feature_names = list(X_train.columns), class_names = True)
plt.show()
# Out:
# Confusion Matrix is:
# [[ 96  39]
#  [ 34 136]]
# Accuracy is : 0.760655737704918
# Report
#               precision    recall  f1-score   support
#
#            0       0.71      0.74      0.72       130
#            1       0.80      0.78      0.79       175
#
#     accuracy                           0.76       305
#    macro avg       0.76      0.76      0.76       305
# weighted avg       0.76      0.76      0.76       305

# %%
# save clf model
from joblib import dump, load
dump(clf, '../Models/Meta_only/CNNMeta_dt.joblib')
# Out:
# ['../Models/Meta_only/CNNMeta_dt.joblib']

# %%
# function for Decision tree, and random forest testing
def Test_DT(path_train,path_test,model_name):
    Train = pd.read_csv(path_train)
    Test = pd.read_csv(path_test)
    
    X_train = Train.iloc[:,:-1]
    Y_train = Train.iloc[:,-1]

    X_test = Test.iloc[:,:-1]
    Y_test = Test.iloc[:,-1]

    #binarize the target
    Y_train_binary = Y_train.apply(lambda x: 1 if x > 0 else 0)
    Y_test_binary = Y_test.apply(lambda x: 1 if x > 0 else 0)

    model = load(model_name)

    Y_pred = model.predict(X_test)
    
    cm = confusion_matrix(Y_pred, Y_test_binary)
    print(cm)
    print(classification_report(Y_test_binary, Y_pred, digits=4))

# %%
#test on each dataset for decision tree
print("Cle test")
path_train = 'cle_metadata_cnn_train.csv'
path_test = 'cle_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_dt.joblib'
Test_DT(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_cnn_train.csv'
path_test = 'vir_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_dt.joblib'
Test_DT(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_cnn_train.csv'
path_test = 'hun_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_dt.joblib'
Test_DT(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_cnn_train.csv'
path_test = 'swi_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_dt.joblib'
Test_DT(path_train,path_test,model)
# Out:
# Cle test
# [[39 11]
#  [13 37]]
#               precision    recall  f1-score   support
#
#            0     0.7800    0.7500    0.7647        52
#            1     0.7400    0.7708    0.7551        48
#
#     accuracy                         0.7600       100
#    macro avg     0.7600    0.7604    0.7599       100
# weighted avg     0.7608    0.7600    0.7601       100
#
# ==================
# vir test
# [[ 8  9]
#  [ 7 42]]
#               precision    recall  f1-score   support
#
#            0     0.4706    0.5333    0.5000        15
#            1     0.8571    0.8235    0.8400        51
#
#     accuracy                         0.7576        66
#    macro avg     0.6639    0.6784    0.6700        66
# weighted avg     0.7693    0.7576    0.7627        66
#
# ==================
# hun test
# [[48  9]
#  [12 29]]
#               precision    recall  f1-score   support
#
#            0     0.8421    0.8000    0.8205        60
#            1     0.7073    0.7632    0.7342        38
#
#     accuracy                         0.7857        98
#    macro avg     0.7747    0.7816    0.7773        98
# weighted avg     0.7898    0.7857    0.7870        98
#
# ==================
# swi test
# [[ 1 10]
#  [ 2 28]]
#               precision    recall  f1-score   support
#
#            0     0.0909    0.3333    0.1429         3
#            1     0.9333    0.7368    0.8235        38
#
#     accuracy                         0.7073        41
#    macro avg     0.5121    0.5351    0.4832        41
# weighted avg     0.8717    0.7073    0.7737        41

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier(n_estimators=100, random_state=42)
classifier.fit(X_train, Y_train_binary)
Y_pred = classifier.predict(X_test)
cm = confusion_matrix(Y_pred, Y_test_binary)
print(cm)
print(classification_report(Y_test_binary, Y_pred))
# Out:
# [[ 99  14]
#  [ 31 161]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.76      0.81       130
#            1       0.84      0.92      0.88       175
#
#     accuracy                           0.85       305
#    macro avg       0.86      0.84      0.85       305
# weighted avg       0.85      0.85      0.85       305

# %%
dump(classifier, '../Models/Meta_only/CNNMeta_rf.joblib')
# Out:
# ['../Models/Meta_only/CNNMeta_rf.joblib']

# %%
#test on each dataset for Random Forest
print("Cle test")
path_train = 'cle_metadata_cnn_train.csv'
path_test = 'cle_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_rf.joblib'
Test_DT(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_cnn_train.csv'
path_test = 'vir_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_rf.joblib'
Test_DT(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_cnn_train.csv'
path_test = 'hun_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_rf.joblib'
Test_DT(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_cnn_train.csv'
path_test = 'swi_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_rf.joblib'
Test_DT(path_train,path_test,model)
# Out:
# Cle test
# [[42  5]
#  [10 43]]
#               precision    recall  f1-score   support
#
#            0     0.8936    0.8077    0.8485        52
#            1     0.8113    0.8958    0.8515        48
#
#     accuracy                         0.8500       100
#    macro avg     0.8525    0.8518    0.8500       100
# weighted avg     0.8541    0.8500    0.8499       100
#
# ==================
# vir test
# [[ 6  4]
#  [ 9 47]]
#               precision    recall  f1-score   support
#
#            0     0.6000    0.4000    0.4800        15
#            1     0.8393    0.9216    0.8785        51
#
#     accuracy                         0.8030        66
#    macro avg     0.7196    0.6608    0.6793        66
# weighted avg     0.7849    0.8030    0.7879        66
#
# ==================
# hun test
# [[50  3]
#  [10 35]]
#               precision    recall  f1-score   support
#
#            0     0.9434    0.8333    0.8850        60
#            1     0.7778    0.9211    0.8434        38
#
#     accuracy                         0.8673        98
#    macro avg     0.8606    0.8772    0.8642        98
# weighted avg     0.8792    0.8673    0.8688        98
#
# ==================
# swi test
# [[ 1  2]
#  [ 2 36]]
#               precision    recall  f1-score   support
#
#            0     0.3333    0.3333    0.3333         3
#            1     0.9474    0.9474    0.9474        38
#
#     accuracy                         0.9024        41
#    macro avg     0.6404    0.6404    0.6404        41
# weighted avg     0.9024    0.9024    0.9024        41

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
svc = SVC()
svc.fit(X_train, Y_train_binary.values.ravel())
y_pred = svc.predict(X_test)
print(confusion_matrix(Y_test_binary, y_pred))
print(classification_report(Y_test_binary, y_pred))
# Out:
# [[ 96  34]
#  [ 13 162]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.74      0.80       130
#            1       0.83      0.93      0.87       175
#
#     accuracy                           0.85       305
#    macro avg       0.85      0.83      0.84       305
# weighted avg       0.85      0.85      0.84       305

# %%
import joblib
joblib.dump(svc, "../Models/Meta_only/CNNMeta_svm.pkl")
# Out:
# ['../Models/Meta_only/CNNMeta_svm.pkl']

# %%
#test on each dataset for SVM
print("Cle test")
path_train = 'cle_metadata_cnn_train.csv'
path_test = 'cle_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_svm.pkl'
Test_DT(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_cnn_train.csv'
path_test = 'vir_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_svm.pkl'
Test_DT(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_cnn_train.csv'
path_test = 'hun_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_svm.pkl'
Test_DT(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_cnn_train.csv'
path_test = 'swi_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_svm.pkl'
Test_DT(path_train,path_test,model)
# Out:
# Cle test
# [[41  5]
#  [11 43]]
#               precision    recall  f1-score   support
#
#            0     0.8913    0.7885    0.8367        52
#            1     0.7963    0.8958    0.8431        48
#
#     accuracy                         0.8400       100
#    macro avg     0.8438    0.8421    0.8399       100
# weighted avg     0.8457    0.8400    0.8398       100
#
# ==================
# vir test
# [[ 4  2]
#  [11 49]]
#               precision    recall  f1-score   support
#
#            0     0.6667    0.2667    0.3810        15
#            1     0.8167    0.9608    0.8829        51
#
#     accuracy                         0.8030        66
#    macro avg     0.7417    0.6137    0.6319        66
# weighted avg     0.7826    0.8030    0.7688        66
#
# ==================
# hun test
# [[50  3]
#  [10 35]]
#               precision    recall  f1-score   support
#
#            0     0.9434    0.8333    0.8850        60
#            1     0.7778    0.9211    0.8434        38
#
#     accuracy                         0.8673        98
#    macro avg     0.8606    0.8772    0.8642        98
# weighted avg     0.8792    0.8673    0.8688        98
#
# ==================
# swi test
# [[ 1  3]
#  [ 2 35]]
#               precision    recall  f1-score   support
#
#            0     0.2500    0.3333    0.2857         3
#            1     0.9459    0.9211    0.9333        38
#
#     accuracy                         0.8780        41
#    macro avg     0.5980    0.6272    0.6095        41
# weighted avg     0.8950    0.8780    0.8859        41

# %% [markdown]
# # Bayesian Classifier

# %%
from sklearn.naive_bayes import GaussianNB

classifier = GaussianNB()
classifier.fit(X_train, Y_train_binary)
Y_pred = classifier.predict(X_test)
cm = confusion_matrix(Y_pred, Y_test_binary)
print(cm)
print(classification_report(Y_test_binary, Y_pred))

dump(clf, '../Models/Meta_only/CNNMeta_NB.joblib')
# Out:
# [[107  23]
#  [ 23 152]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82       130
#            1       0.87      0.87      0.87       175
#
#     accuracy                           0.85       305
#    macro avg       0.85      0.85      0.85       305
# weighted avg       0.85      0.85      0.85       305
# ['../Models/Meta_only/CNNMeta_NB.joblib']

# %%
print("Cle test")
path_train = 'cle_metadata_cnn_train.csv'
path_test = 'cle_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_NB.joblib'
Test_DT(path_train,path_test,model)

print("==================")

print("vir test")
path_train = 'vir_metadata_cnn_train.csv'
path_test = 'vir_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_NB.joblib'
Test_DT(path_train,path_test,model)

print("==================")
print("hun test")
path_train = 'hun_metadata_cnn_train.csv'
path_test = 'hun_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_NB.joblib'
Test_DT(path_train,path_test,model)

print("==================")
print("swi test")
path_train = 'swi_metadata_cnn_train.csv'
path_test = 'swi_metadata_cnn_test.csv'
model = '../Models/Meta_only/CNNMeta_NB.joblib'
Test_DT(path_train,path_test,model)
# Out:
# Cle test
# [[39 11]
#  [13 37]]
#               precision    recall  f1-score   support
#
#            0     0.7800    0.7500    0.7647        52
#            1     0.7400    0.7708    0.7551        48
#
#     accuracy                         0.7600       100
#    macro avg     0.7600    0.7604    0.7599       100
# weighted avg     0.7608    0.7600    0.7601       100
#
# ==================
# vir test
# [[ 8  9]
#  [ 7 42]]
#               precision    recall  f1-score   support
#
#            0     0.4706    0.5333    0.5000        15
#            1     0.8571    0.8235    0.8400        51
#
#     accuracy                         0.7576        66
#    macro avg     0.6639    0.6784    0.6700        66
# weighted avg     0.7693    0.7576    0.7627        66
#
# ==================
# hun test
# [[48  9]
#  [12 29]]
#               precision    recall  f1-score   support
#
#            0     0.8421    0.8000    0.8205        60
#            1     0.7073    0.7632    0.7342        38
#
#     accuracy                         0.7857        98
#    macro avg     0.7747    0.7816    0.7773        98
# weighted avg     0.7898    0.7857    0.7870        98
#
# ==================
# swi test
# [[ 1 10]
#  [ 2 28]]
#               precision    recall  f1-score   support
#
#            0     0.0909    0.3333    0.1429         3
#            1     0.9333    0.7368    0.8235        38
#
#     accuracy                         0.7073        41
#    macro avg     0.5121    0.5351    0.4832        41
# weighted avg     0.8717    0.7073    0.7737        41
