# %%
import numpy as np
import pandas as pd
import keras.backend as K
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf

# %%
def CNN(path_train,path_test):
    #Split the data
    Train = pd.read_csv(path_train)
    Test = pd.read_csv(path_test)
    
    X_train = Train.iloc[:,:-1]
    Y_train = Train.iloc[:,-1]

    X_test = Test.iloc[:,:-1]
    Y_test = Test.iloc[:,-1]

    #binarize the target
    Y_train_binary = Y_train.apply(lambda x: 1 if x > 0 else 0)
    Y_test_binary = Y_test.apply(lambda x: 1 if x > 0 else 0)

    # define the model architecture
    model = Sequential()
    model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(22,1)))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(2, activation='sigmoid'))

    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(X_train, Y_train_binary, epochs=10, batch_size=32)
    Y_pred = model.predict(X_test).argmax(axis=1)
    
    cm = confusion_matrix(Y_pred, Y_test_binary)
    print(cm)
    print(classification_report(Y_test_binary, Y_pred))
    return model

def wholeData(path_train,path_test):
    #Split the data
    Train = pd.read_csv(path_train)
    Test = pd.read_csv(path_test)
    
    X_train = Train.iloc[:,:-1]
    Y_train = Train.iloc[:,-1]
    
    X_test = Test.iloc[:,:-1]
    Y_test = Test.iloc[:,-1]
    
    X_entire = pd.concat([X_train,X_test])
    Y_entire = pd.concat([Y_train,Y_test])
    return X_entire,Y_entire

# %% [markdown]
# # Cleveland

# %%
path_train = './TrainTestData/cle_train.csv'
path_test = './TrainTestData/cle_test.csv'
model = CNN(path_train,path_test)

model2 = Sequential()
model2.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(22,1)))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Flatten())
model2.add(Dense(128, activation='relu'))

model2.set_weights(model.get_weights()[:-2]) 

model2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

X_entire,labels = wholeData(path_train,path_test)

Y_predictions = model2.predict(X_entire)
Y_predictions.shape

temp = pd.DataFrame(Y_predictions)

labels = labels.reset_index()
labels = labels.drop(columns = ['index'])

cle_processed = pd.concat([temp,labels],axis = 1)

cle_processed.to_csv('cle_metadata.csv',ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 path_train = './TrainTestData/cle_train.csv'
#       2 path_test = './TrainTestData/cle_test.csv'
# ----> 3 model = CNN(path_train,path_test)
#       5 model2 = Sequential()
#       6 model2.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(22,1)))
#
# Cell In[3], line 3, in CNN(path_train, path_test)
#       1 def CNN(path_train,path_test):
#       2     #Split the data
# ----> 3     Train = pd.read_csv(path_train)
#       4     Test = pd.read_csv(path_test)
#       6     X_train = Train.iloc[:,:-1]
#
# File D:\Anaconda\envs\GPU\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\Anaconda\envs\GPU\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File D:\Anaconda\envs\GPU\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File D:\Anaconda\envs\GPU\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File D:\Anaconda\envs\GPU\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File D:\Anaconda\envs\GPU\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File D:\Anaconda\envs\GPU\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './TrainTestData/cle_train.csv'

# %% [markdown]
# # Virginia

# %%
path_train = './TrainTestData/vir_train.csv'
path_test = './TrainTestData/vir_test.csv'
model = CNN(path_train,path_test)

model2 = Sequential()
model2.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(22,1)))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Flatten())
model2.add(Dense(128, activation='relu'))

model2.set_weights(model.get_weights()[:-2]) 

model2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

X_entire,labels = wholeData(path_train,path_test)

Y_predictions = model2.predict(X_entire)
Y_predictions.shape

temp = pd.DataFrame(Y_predictions)

labels = labels.reset_index()
labels = labels.drop(columns = ['index'])

cle_processed = pd.concat([temp,labels],axis = 1)

cle_processed.to_csv('vir_metadata.csv')
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6135 - accuracy: 0.6000
# Epoch 2/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5589 - accuracy: 0.7286
# Epoch 3/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5714 - accuracy: 0.7286
# Epoch 4/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5433 - accuracy: 0.7286
# Epoch 5/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5344 - accuracy: 0.7286
# Epoch 6/10
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5184 - accuracy: 0.7286
# Epoch 7/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5025 - accuracy: 0.7286
# Epoch 8/10
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4879 - accuracy: 0.7357
# Epoch 9/10
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4787 - accuracy: 0.7857
# Epoch 10/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4706 - accuracy: 0.7714
# 2/2 [==============================] - 0s 3ms/step
# [[ 4  4]
#  [ 9 43]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.31      0.38        13
#            1       0.83      0.91      0.87        47
#
#     accuracy                           0.78        60
#    macro avg       0.66      0.61      0.62        60
# weighted avg       0.76      0.78      0.76        60
#
# 7/7 [==============================] - 0s 2ms/step

# %% [markdown]
# # Hungarian

# %%
path_train = './TrainTestData/hun_train.csv'
path_test = './TrainTestData/hun_test.csv'
model = CNN(path_train,path_test)

model2 = Sequential()
model2.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(22,1)))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Flatten())
model2.add(Dense(128, activation='relu'))

model2.set_weights(model.get_weights()[:-2]) 

model2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

X_entire,labels = wholeData(path_train,path_test)

Y_predictions = model2.predict(X_entire)
Y_predictions.shape

temp = pd.DataFrame(Y_predictions)

labels = labels.reset_index()
labels = labels.drop(columns = ['index'])

cle_processed = pd.concat([temp,labels],axis = 1)

cle_processed.to_csv('hun_metadata.csv')
# Out:
# Epoch 1/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5973 - accuracy: 0.7073
# Epoch 2/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4283 - accuracy: 0.8098
# Epoch 3/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3498 - accuracy: 0.8537
# Epoch 4/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3334 - accuracy: 0.8488
# Epoch 5/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3154 - accuracy: 0.8683
# Epoch 6/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2975 - accuracy: 0.8634
# Epoch 7/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2689 - accuracy: 0.8732
# Epoch 8/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2498 - accuracy: 0.9024
# Epoch 9/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3250 - accuracy: 0.8732
# Epoch 10/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2720 - accuracy: 0.8976
# 3/3 [==============================] - 0s 3ms/step
# [[53 10]
#  [ 4 22]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88        57
#            1       0.85      0.69      0.76        32
#
#     accuracy                           0.84        89
#    macro avg       0.84      0.81      0.82        89
# weighted avg       0.84      0.84      0.84        89
#
# 10/10 [==============================] - 0s 2ms/step

# %% [markdown]
# # Switzerland

# %%
path_train = './TrainTestData/swi_train.csv'
path_test = './TrainTestData/swi_test.csv'
model = CNN(path_train,path_test)

model2 = Sequential()
model2.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(22,1)))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
model2.add(MaxPooling1D(pool_size=2))

model2.add(Flatten())
model2.add(Dense(128, activation='relu'))

model2.set_weights(model.get_weights()[:-2]) 

model2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

X_entire,labels = wholeData(path_train,path_test)

Y_predictions = model2.predict(X_entire)
Y_predictions.shape

temp = pd.DataFrame(Y_predictions)

labels = labels.reset_index()
labels = labels.drop(columns = ['index'])

cle_processed = pd.concat([temp,labels],axis = 1)

cle_processed.to_csv('swi_metadata.csv')
# Out:
# Epoch 1/10
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4622 - accuracy: 0.7558
# Epoch 2/10
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2721 - accuracy: 0.9302
# Epoch 3/10
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3161 - accuracy: 0.9302
# Epoch 4/10
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2574 - accuracy: 0.9302
# Epoch 5/10
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2438 - accuracy: 0.9302
# Epoch 6/10
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2446 - accuracy: 0.9302
# Epoch 7/10
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2419 - accuracy: 0.9302
# Epoch 8/10
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2259 - accuracy: 0.9302
# Epoch 9/10
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2166 - accuracy: 0.9302
# Epoch 10/10
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2108 - accuracy: 0.9302
# 2/2 [==============================] - 0s 3ms/step
# [[ 0  0]
#  [ 2 35]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.95      1.00      0.97        35
#
#     accuracy                           0.95        37
#    macro avg       0.47      0.50      0.49        37
# weighted avg       0.89      0.95      0.92        37
#
# 4/4 [==============================] - 0s 2ms/step
# D:\Anaconda\envs\GPU\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\envs\GPU\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\envs\GPU\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
