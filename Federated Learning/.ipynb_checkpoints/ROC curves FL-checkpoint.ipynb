# %%
import numpy as np
import random
import cv2
import os
from imutils import paths
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.neural_network import MLPClassifier

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Activation, Flatten, Dense, Dropout,SimpleRNN
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K
from sklearn.metrics import confusion_matrix, classification_report

# %%
data_files = ['cle_metadata', 'vir_metadata', 'hun_metadata', 'swi_metadata']

for file in data_files:
    data = pd.read_csv('../Metadata Learning/' + file + '.csv', index_col = 0)
    
    X = data.iloc[:, :-1]
    Y = data.iloc[:, -1]
    
    Y_binary = Y.apply(lambda x: 1 if x > 0 else 0)
    
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 42)
    
    train = pd.concat([X_train, y_train], axis=1)
    test = pd.concat([X_test, y_test], axis=1)
    
    train.to_csv('../TrainTestData/'+ file + "_train.csv")
    test.to_csv('../TrainTestData/' + file + "_test.csv")

# %%
#binarize the labels
lb = LabelBinarizer()

import pandas as pd

data_files = ['cle_metadata_train.csv','cle_metadata_test.csv','hun_metadata_train.csv','hun_metadata_test.csv','swi_metadata_train.csv','swi_metadata_test.csv','vir_metadata_train.csv','vir_metadata_test.csv']

datasets = {}

for file in data_files:
    data = pd.read_csv('../TrainTestData/' + file)
    
    X = data.iloc[:, :-1]
    Y = data.iloc[:, -1]
    
    Y_binary = Y.apply(lambda x: 1 if x > 0 else 0)
    
    # Extract the name from the file path
    name = file.split('.')[0]
    
    # Store the dataset components in a dictionary
    datasets[name] = {'X': X, 'Y': Y, 'Y_binary': Y_binary}

# Unpack the dictionary values in a loop
variables = ['cle', 'hun', 'swi', 'vir']
train_test = ['train', 'test']

for var in variables:
    for tt in train_test:
        X, Y, Y_binary = datasets[f'{var}_metadata_{tt}'].values()
        globals()[f'{var}_X_{tt}'] = X
        globals()[f'{var}_Y_{tt}'] = Y
        globals()[f'{var}_Y_{tt}_binary'] = Y_binary

# %%
X_test = pd.concat([cle_X_test,hun_X_test,swi_X_test,vir_X_test, swi_X_train])
y_test = pd.concat([cle_Y_test_binary,hun_Y_test_binary,swi_Y_test_binary,vir_Y_test_binary,swi_Y_train_binary])

X_train = pd.concat([cle_X_train,hun_X_train,vir_X_train])
y_train = pd.concat([cle_Y_train_binary,hun_Y_train_binary,vir_Y_train_binary])

# %%
def create_clients():
    cle_zip = list(zip(cle_X_train.values,cle_Y_train_binary))
    hun_zip = list(zip(hun_X_train.values,hun_Y_train_binary))
    vir_zip = list(zip(vir_X_train.values,vir_Y_train_binary))
    #swi_zip = list(zip(swi_X_train.values,swi_Y_train_binary))
    
    shards = [cle_zip, hun_zip, vir_zip]
    client_names = ["client_1","client_2","client_3"]
    dic = {client_names[i] : shards[i] for i in range(len(client_names))}
    return dic


def batch_data(data_shard, bs=32):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    return dataset.shuffle(len(label)).batch(bs)


class CNN:
    @staticmethod
    def build(shape, classes):
        model = Sequential()
        model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(64,1)))
        model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
        model.add(MaxPooling1D(pool_size=2))

        model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
        model.add(MaxPooling1D(pool_size=2))

        model.add(Flatten())
        model.add(Dense(256, activation='relu'))
        model.add(Dense(2, activation='sigmoid'))

        model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
        return model
    

def weight_scalling_factor(clients_trn_data, client_name):
    client_names = list(clients_trn_data.keys())
    #get the bs
    bs = list(clients_trn_data[client_name])[0][0].shape[0]
    #first calculate the total training data points across clinets
    global_count = sum([tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy() for client_name in client_names])*bs
    # get the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy()*bs
    return local_count/global_count


def scale_model_weights(weight, scalar):
    '''function for scaling a models weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final


def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights. The is equivalent to scaled avg of the weights'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
        
    return avg_grad


def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    length = len(y_test)
    Y_test = tf.reshape(Y_test,(length,1))
    loss = cce(Y_test, logits)
    acc = accuracy_score(tf.argmax(logits, axis=1), Y_test)
    print('comm_round: {} | global_acc: {:.3%} | global_loss: {}'.format(comm_round, acc, loss))
    return acc, loss

# %%
#create clients
clients = create_clients()

#process and batch the training data for each client
clients_batched = dict()
for (client_name, data) in clients.items():
    clients_batched[client_name] = batch_data(data)
    
#process and batch the test set  
test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

comms_round = 100
    
#create optimizer
lr = 0.01 
loss='sparse_categorical_crossentropy'
metrics = ['accuracy']
optimizer = tf.keras.optimizers.legacy.SGD(lr=lr, decay=lr / comms_round, momentum=0.9) 
64,1
#initialize global model
smlp_global = CNN()
global_model = smlp_global.build(64, 2)
        
#commence global training loop
for comm_round in range(comms_round):
            
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()
    
    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(clients_batched.keys())
    random.shuffle(client_names)
    
    #loop through each client and create new local model
    for client in client_names:
        smlp_local = CNN()
        local_model = smlp_local.build(64, 2)
        local_model.compile(loss=loss, 
                      optimizer=optimizer, 
                      metrics=metrics)
        
        #set local model weight to the weight of the global model
        local_model.set_weights(global_weights)
        
        #fit local model with client's data
        local_model.fit(clients_batched[client], epochs=1, verbose=0)
        
        #scale the model weights and add to list
        scaling_factor = weight_scalling_factor(clients_batched, client)
        scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
        scaled_local_weight_list.append(scaled_weights)
        
        #clear session to free memory after each communication round
        K.clear_session()
        
    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)
    
    #update global model 
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    for(X_test, Y_test) in test_batched:
        global_acc, global_loss = test_model(X_test, Y_test, global_model, comm_round)
        SGD_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(len(y_train)).batch(250)
        smlp_SGD = CNN()
        SGD_model = smlp_SGD.build(64, 2) 

        SGD_model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# fit the SGD training data to model
_ = SGD_model.fit(SGD_dataset, epochs=100, verbose=0)

#test the SGD global model and print out metrics
for(X_test, Y_test) in test_batched:
        SGD_acc, SGD_loss = test_model(X_test, Y_test, SGD_model, 1)
# Out:
# D:\Anaconda\envs\GPU\lib\site-packages\keras\optimizers\legacy\gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 0 | global_acc: 81.543% | global_loss: 0.6728823184967041
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 1 | global_acc: 84.573% | global_loss: 0.6501668095588684
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 2 | global_acc: 82.920% | global_loss: 0.633894681930542
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 3 | global_acc: 83.471% | global_loss: 0.6127176880836487
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 4 | global_acc: 83.196% | global_loss: 0.595367968082428
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 5 | global_acc: 82.369% | global_loss: 0.5838444232940674
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 6 | global_acc: 84.022% | global_loss: 0.569238007068634
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 7 | global_acc: 82.645% | global_loss: 0.5636849999427795
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 8 | global_acc: 84.298% | global_loss: 0.554826557636261
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 9 | global_acc: 82.645% | global_loss: 0.5556642413139343
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 10 | global_acc: 84.848% | global_loss: 0.5480755567550659
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 11 | global_acc: 81.543% | global_loss: 0.5537930727005005
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 12 | global_acc: 85.124% | global_loss: 0.5416678190231323
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 13 | global_acc: 84.573% | global_loss: 0.5470775961875916
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 14 | global_acc: 84.298% | global_loss: 0.5459166169166565
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 15 | global_acc: 84.022% | global_loss: 0.5454524159431458
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 16 | global_acc: 84.022% | global_loss: 0.5449424386024475
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 17 | global_acc: 85.124% | global_loss: 0.5398406386375427
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 18 | global_acc: 82.369% | global_loss: 0.5519688725471497
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 19 | global_acc: 85.399% | global_loss: 0.5343671441078186
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 20 | global_acc: 84.573% | global_loss: 0.5465395450592041
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 21 | global_acc: 84.848% | global_loss: 0.5420230627059937
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 22 | global_acc: 85.124% | global_loss: 0.5394193530082703
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 23 | global_acc: 84.848% | global_loss: 0.543507993221283
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 24 | global_acc: 84.848% | global_loss: 0.5424507260322571
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 25 | global_acc: 84.848% | global_loss: 0.5420209765434265
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 26 | global_acc: 85.124% | global_loss: 0.5370603799819946
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 27 | global_acc: 85.124% | global_loss: 0.5419032573699951
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 28 | global_acc: 85.399% | global_loss: 0.5342597365379333
# 12/12 [==============================] - 0s 3ms/step
# comm_round:
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 79 | global_acc: 85.399% | global_loss: 0.5358712673187256
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 80 | global_acc: 85.675% | global_loss: 0.5359166860580444
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 81 | global_acc: 85.399% | global_loss: 0.5378575325012207
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 82 | global_acc: 85.950% | global_loss: 0.5322971940040588
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 83 | global_acc: 85.399% | global_loss: 0.5387828946113586
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 84 | global_acc: 85.399% | global_loss: 0.535929799079895
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 85 | global_acc: 85.399% | global_loss: 0.5366076827049255
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 86 | global_acc: 85.950% | global_loss: 0.5346940755844116
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 87 | global_acc: 85.675% | global_loss: 0.5358750224113464
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 88 | global_acc: 85.399% | global_loss: 0.539768636226654
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 89 | global_acc: 85.950% | global_loss: 0.5358322858810425
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 90 | global_acc: 85.675% | global_loss: 0.5361203551292419
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 91 | global_acc: 85.124% | global_loss: 0.5438796281814575
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 92 | global_acc: 85.399% | global_loss: 0.538751482963562
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 93 | global_acc: 85.399% | global_loss: 0.5394648313522339
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 94 | global_acc: 85.675% | global_loss: 0.5373278260231018
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 95 | global_acc: 85.399% | global_loss: 0.5383009314537048
# 12/12 [==============================] - 0s 2ms/step
# comm_round: 96 | global_acc: 85.399% | global_loss: 0.5407248139381409
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 97 | global_acc: 86.226% | global_loss: 0.5361177325248718
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 98 | global_acc: 85.399% | global_loss: 0.5411148071289062
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 99 | global_acc: 85.950% | global_loss: 0.537331223487854
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 1 | global_acc: 85.399% | global_loss: 0.538568913936615

# %%
Y_predictions = np.argmax(SGD_model.predict(X_test),axis = 1)
# Out:
# 12/12 [==============================] - 0s 3ms/step

# %%
CNN_FL_pred = Y_predictions.copy()
CNN_FL_label = Y_test

# %%
plt.figure(0).clf()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
    
#fit logistic regression model and plot ROC curve
fpr, tpr, _ = metrics.roc_curve(CNN_FL_label, CNN_FL_pred)
auc = round(metrics.roc_auc_score(CNN_FL_label, CNN_FL_pred), 4)
plt.plot([0, 1], [0, 1], 'k--')  # Random guessing line
plt.plot(fpr,tpr,label="Federated Learning CNN, AUC="+str(auc))

#add legend
plt.legend()
plt.show()

# %% [markdown]
# # CNN

# %%
Train = pd.read_csv('../TrainTestData/com_train.csv')
Test = pd.read_csv('../TrainTestData/com_train.csv')
    
X_train = Train.iloc[:,:-1]
Y_train = Train.iloc[:,-1]

X_test = Test.iloc[:,:-1]
Y_test = Test.iloc[:,-1]

#binarize the target
Y_train_binary = Y_train.apply(lambda x: 1 if x > 0 else 0)
Y_test_binary = Y_test.apply(lambda x: 1 if x > 0 else 0)

# CNN
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(22,1)))
model.add(Conv1D(filters=256, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

model.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
model.fit(X_train, Y_train_binary, epochs=20, batch_size=32)
Y_pred = model.predict(X_test).argmax(axis=1)

CNN_pred = Y_pred
CNN_label = Y_test_binary
# Out:
# Epoch 1/20
# 21/21 [==============================] - 1s 22ms/step - loss: 0.5900 - accuracy: 0.6941
# Epoch 2/20
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4976 - accuracy: 0.7655
# Epoch 3/20
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4667 - accuracy: 0.7981
# Epoch 4/20
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4367 - accuracy: 0.8106
# Epoch 5/20
# 21/21 [==============================] - 0s 21ms/step - loss: 0.4407 - accuracy: 0.7919
# Epoch 6/20
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4224 - accuracy: 0.8152
# Epoch 7/20
# 21/21 [==============================] - 0s 21ms/step - loss: 0.4261 - accuracy: 0.8261
# Epoch 8/20
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4069 - accuracy: 0.8199
# Epoch 9/20
# 21/21 [==============================] - 0s 21ms/step - loss: 0.4140 - accuracy: 0.8261
# Epoch 10/20
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4000 - accuracy: 0.8152
# Epoch 11/20
# 21/21 [==============================] - 0s 21ms/step - loss: 0.3798 - accuracy: 0.8307
# Epoch 12/20
# 21/21 [==============================] - 0s 22ms/step - loss: 0.3836 - accuracy: 0.8261
# Epoch 13/20
# 21/21 [==============================] - 0s 21ms/step - loss: 0.3675 - accuracy: 0.8385
# Epoch 14/20
# 21/21 [==============================] - 0s 21ms/step - loss: 0.3732 - accuracy: 0.8385
# Epoch 15/20
# 21/21 [==============================] - 0s 22ms/step - loss: 0.3581 - accuracy: 0.8509
# Epoch 16/20
# 21/21 [==============================] - 0s 21ms/step - loss: 0.3388 - accuracy: 0.8587
# Epoch 17/20
# 21/21 [==============================] - 0s 22ms/step - loss: 0.3435 - accuracy: 0.8447
# Epoch 18/20
# 21/21 [==============================] - 0s 21ms/step - loss: 0.3387 - accuracy: 0.8509
# Epoch 19/20
# 21/21 [==============================] - 0s 22ms/step - loss: 0.3552 - accuracy: 0.8602
# Epoch 20/20
# 21/21 [==============================] - 0s 21ms/step - loss: 0.3542 - accuracy: 0.8525
# 21/21 [==============================] - 0s 6ms/step

# %%
plt.figure(0).clf()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
    
#FL CNN
fpr, tpr, _ = metrics.roc_curve(CNN_FL_label, CNN_FL_pred)
auc = round(metrics.roc_auc_score(CNN_FL_label, CNN_FL_pred), 4)
plt.plot([0, 1], [0, 1], 'k--')  # Random guessing line
plt.plot(fpr,tpr,label="Federated Learning CNN, AUC="+str(auc))

#CNN
fpr, tpr, _ = metrics.roc_curve(CNN_label, CNN_pred)
auc = round(metrics.roc_auc_score(CNN_label, CNN_pred), 4)
plt.plot(fpr,tpr,label="Traditional CNN, AUC="+str(auc))

#add legend
plt.legend()
plt.show()

# %% [markdown]
# # RNN FL

# %%
data_files = ['cle_metadata', 'vir_metadata', 'hun_metadata', 'swi_metadata']

for file in data_files:
    data = pd.read_csv('../Metadata Learning/' + file + '.csv', index_col = 0)
    
    X = data.iloc[:, :-1]
    Y = data.iloc[:, -1]
    
    Y_binary = Y.apply(lambda x: 1 if x > 0 else 0)
    
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 42)
    
    train = pd.concat([X_train, y_train], axis=1)
    test = pd.concat([X_test, y_test], axis=1)
    
    train.to_csv('../TrainTestData/'+ file + "_train.csv")
    test.to_csv('../TrainTestData/' + file + "_test.csv")
    
#binarize the labels
lb = LabelBinarizer()

import pandas as pd

data_files = ['cle_metadata_train.csv','cle_metadata_test.csv','hun_metadata_train.csv','hun_metadata_test.csv','swi_metadata_train.csv','swi_metadata_test.csv','vir_metadata_train.csv','vir_metadata_test.csv']

datasets = {}

for file in data_files:
    data = pd.read_csv('../TrainTestData/' + file)
    
    X = data.iloc[:, :-1]
    Y = data.iloc[:, -1]
    
    Y_binary = Y.apply(lambda x: 1 if x > 0 else 0)
    
    # Extract the name from the file path
    name = file.split('.')[0]
    
    # Store the dataset components in a dictionary
    datasets[name] = {'X': X, 'Y': Y, 'Y_binary': Y_binary}

# Unpack the dictionary values in a loop
variables = ['cle', 'hun', 'swi', 'vir']
train_test = ['train', 'test']

for var in variables:
    for tt in train_test:
        X, Y, Y_binary = datasets[f'{var}_metadata_{tt}'].values()
        globals()[f'{var}_X_{tt}'] = X
        globals()[f'{var}_Y_{tt}'] = Y
        globals()[f'{var}_Y_{tt}_binary'] = Y_binary
        
X_test = pd.concat([cle_X_test,hun_X_test,swi_X_test,vir_X_test, swi_X_train])
y_test = pd.concat([cle_Y_test_binary,hun_Y_test_binary,swi_Y_test_binary,vir_Y_test_binary,swi_Y_train_binary])

X_train = pd.concat([cle_X_train,hun_X_train,vir_X_train])
y_train = pd.concat([cle_Y_train_binary,hun_Y_train_binary,vir_Y_train_binary])

class RNN:
    @staticmethod
    def build(shape, classes):
        model = Sequential()
        model.add(SimpleRNN(units=64, return_sequences=True, input_shape=(64,1)))
        model.add(SimpleRNN(units=32, return_sequences=True))
        model.add(SimpleRNN(units=16))
        model.add(Dense(units=2, activation='sigmoid'))

        model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
        return model

#create clients
clients = create_clients()

#process and batch the training data for each client
clients_batched = dict()
for (client_name, data) in clients.items():
    clients_batched[client_name] = batch_data(data)
    
#process and batch the test set  
test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

comms_round = 100
    
#create optimizer
lr = 0.01 
loss='sparse_categorical_crossentropy'
metrics = ['accuracy']
optimizer = tf.keras.optimizers.legacy.SGD(lr=lr, decay=lr / comms_round, momentum=0.9) 

#initialize global model
smlp_global = RNN()
global_model = smlp_global.build(64, 2)
        
#commence global training loop
for comm_round in range(comms_round):
            
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()
    
    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(clients_batched.keys())
    random.shuffle(client_names)
    
    #loop through each client and create new local model
    for client in client_names:
        smlp_local = RNN()
        local_model = smlp_local.build(64, 2)
        local_model.compile(loss=loss, 
                      optimizer=optimizer, 
                      metrics=metrics)
        
        #set local model weight to the weight of the global model
        local_model.set_weights(global_weights)
        
        #fit local model with client's data
        local_model.fit(clients_batched[client], epochs=1, verbose=0)
        
        #scale the model weights and add to list
        scaling_factor = weight_scalling_factor(clients_batched, client)
        scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
        scaled_local_weight_list.append(scaled_weights)
        
        #clear session to free memory after each communication round
        K.clear_session()
        
    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)
    
    #update global model 
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    for(X_test, Y_test) in test_batched:
        global_acc, global_loss = test_model(X_test, Y_test, global_model, comm_round)
        SGD_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(len(y_train)).batch(250)
        smlp_SGD = CNN()
        SGD_model = smlp_SGD.build(64, 2) 

        SGD_model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# fit the SGD training data to model
_ = SGD_model.fit(SGD_dataset, epochs=100, verbose=0)

#test the SGD global model and print out metrics
for(X_test, Y_test) in test_batched:
        SGD_acc, SGD_loss = test_model(X_test, Y_test, SGD_model, 1)
        
Y_predictions = np.argmax(SGD_model.predict(X_test),axis = 1)

RNN_FL_pred = Y_predictions.copy()
RNN_FL_label = Y_test
# Out:
# D:\Anaconda\envs\GPU\lib\site-packages\keras\optimizers\legacy\gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 0 | global_acc: 78.788% | global_loss: 0.601592481136322
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 1 | global_acc: 74.380% | global_loss: 0.5970597863197327
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 2 | global_acc: 80.992% | global_loss: 0.5711454749107361
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 3 | global_acc: 74.656% | global_loss: 0.5913768410682678
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 4 | global_acc: 80.716% | global_loss: 0.5754814147949219
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 5 | global_acc: 76.033% | global_loss: 0.5885799527168274
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 6 | global_acc: 82.094% | global_loss: 0.5752164721488953
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 7 | global_acc: 79.614% | global_loss: 0.5777604579925537
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 8 | global_acc: 82.920% | global_loss: 0.557793915271759
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 9 | global_acc: 81.818% | global_loss: 0.5643441081047058
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 10 | global_acc: 84.022% | global_loss: 0.5666817426681519
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 11 | global_acc: 77.686% | global_loss: 0.5970055460929871
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 12 | global_acc: 83.747% | global_loss: 0.5621618032455444
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 13 | global_acc: 82.094% | global_loss: 0.5625871419906616
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 14 | global_acc: 84.298% | global_loss: 0.5690747499465942
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 15 | global_acc: 82.920% | global_loss: 0.5475460290908813
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 16 | global_acc: 83.747% | global_loss: 0.5599395632743835
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 17 | global_acc: 84.848% | global_loss: 0.5415564179420471
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 18 | global_acc: 81.267% | global_loss: 0.5780775547027588
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 19 | global_acc: 85.399% | global_loss: 0.5353820323944092
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 20 | global_acc: 81.818% | global_loss: 0.5678555965423584
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 21 | global_acc: 83.471% | global_loss: 0.5489080548286438
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 22 | global_acc: 83.471% | global_loss: 0.5675382018089294
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 23 | global_acc: 83.747% | global_loss: 0.5553419589996338
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 24 | global_acc: 82.920% | global_loss: 0.5673415064811707
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 25 | global_acc: 83.196% | global_loss: 0.5568026900291443
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 26 | global_acc: 80.992% | global_loss: 0.5747600197792053
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 27 | global_acc: 84.573% | global_loss: 0.5467652678489685
# 12/12 [==============================] - 0s 3ms/step
# comm_round:
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 78 | global_acc: 84.022% | global_loss: 0.5408909916877747
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 79 | global_acc: 83.196% | global_loss: 0.5547777414321899
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 80 | global_acc: 85.675% | global_loss: 0.547291100025177
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 81 | global_acc: 80.992% | global_loss: 0.5550486445426941
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 82 | global_acc: 85.124% | global_loss: 0.5403543710708618
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 83 | global_acc: 82.094% | global_loss: 0.5530564785003662
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 84 | global_acc: 84.848% | global_loss: 0.5388970971107483
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 85 | global_acc: 81.543% | global_loss: 0.5655980110168457
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 86 | global_acc: 84.573% | global_loss: 0.5383180975914001
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 87 | global_acc: 84.022% | global_loss: 0.5510010719299316
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 88 | global_acc: 83.471% | global_loss: 0.5364217758178711
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 89 | global_acc: 84.298% | global_loss: 0.5491310358047485
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 90 | global_acc: 81.543% | global_loss: 0.5577972531318665
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 91 | global_acc: 84.298% | global_loss: 0.5426793098449707
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 92 | global_acc: 82.094% | global_loss: 0.5405098795890808
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 93 | global_acc: 83.471% | global_loss: 0.5583884716033936
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 94 | global_acc: 82.920% | global_loss: 0.543765664100647
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 95 | global_acc: 82.369% | global_loss: 0.5619442462921143
# 12/12 [==============================] - 0s 3ms/step
# comm_round: 96 | global_acc: 83.196% | global_loss: 0.5418092608451843
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 97 | global_acc: 82.920% | global_loss: 0.5586997866630554
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 98 | global_acc: 83.196% | global_loss: 0.5483188629150391
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 99 | global_acc: 83.196% | global_loss: 0.5359987616539001
# 12/12 [==============================] - 0s 4ms/step
# comm_round: 1 | global_acc: 85.124% | global_loss: 0.5353879332542419
# 12/12 [==============================] - 0s 4ms/step

# %%
from sklearn import metrics

# %%
plt.figure(0).clf()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
    
#FL CNN
fpr, tpr, _ = metrics.roc_curve(CNN_FL_label, CNN_FL_pred)
auc = round(metrics.roc_auc_score(CNN_FL_label, CNN_FL_pred), 4)
plt.plot([0, 1], [0, 1], 'k--')  # Random guessing line
plt.plot(fpr,tpr,label="Federated Learning CNN, AUC="+str(auc))

#CNN
fpr, tpr, _ = metrics.roc_curve(CNN_label, CNN_pred)
auc = round(metrics.roc_auc_score(CNN_label, CNN_pred), 4)
plt.plot(fpr,tpr,label="Traditional CNN, AUC="+str(auc))

#FL RNN
fpr, tpr, _ = metrics.roc_curve(RNN_FL_label, RNN_FL_pred)
auc = round(metrics.roc_auc_score(RNN_FL_label, RNN_FL_pred), 4)
plt.plot(fpr,tpr,label="Federated Learning RNN, AUC="+str(auc))

#add legend
plt.legend()
plt.show()

# %% [markdown]
# # RNN

# %%
#Split the data
Train = pd.read_csv('../TrainTestData/com_train.csv')
Test = pd.read_csv('../TrainTestData/com_test.csv')
    
X_train = Train.iloc[:,:-1]
Y_train = Train.iloc[:,-1]

X_test = Test.iloc[:,:-1]
Y_test = Test.iloc[:,-1]

#binarize the target
Y_train_binary = Y_train.apply(lambda x: 1 if x > 0 else 0)
Y_test_binary = Y_test.apply(lambda x: 1 if x > 0 else 0)

# define the model architecture
model = Sequential()
model.add(SimpleRNN(units=64, return_sequences=True, input_shape=(22, 1)))
model.add(SimpleRNN(units=32, return_sequences=True))
model.add(SimpleRNN(units=16))
model.add(Dense(units=2, activation='sigmoid'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
model.fit(X_train, Y_train_binary, epochs=10, batch_size=32)
Y_pred = model.predict(X_test).argmax(axis=1)

RNN_pred = Y_pred
RNN_label = Y_test_binary
# Out:
# Epoch 1/10
# 21/21 [==============================] - 1s 5ms/step - loss: 0.5214 - accuracy: 0.7655
# Epoch 2/10
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4453 - accuracy: 0.7966
# Epoch 3/10
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4213 - accuracy: 0.8168
# Epoch 4/10
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4065 - accuracy: 0.8168
# Epoch 5/10
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4297 - accuracy: 0.8059
# Epoch 6/10
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4107 - accuracy: 0.8214
# Epoch 7/10
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3942 - accuracy: 0.8307
# Epoch 8/10
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3821 - accuracy: 0.8276
# Epoch 9/10
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3903 - accuracy: 0.8292
# Epoch 10/10
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3713 - accuracy: 0.8354
# 9/9 [==============================] - 0s 2ms/step

# %%
plt.figure(0).clf()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
    
#FL CNN
fpr, tpr, _ = metrics.roc_curve(CNN_FL_label, CNN_FL_pred)
auc = round(metrics.roc_auc_score(CNN_FL_label, CNN_FL_pred), 4)
plt.plot([0, 1], [0, 1], 'k--')  # Random guessing line
plt.plot(fpr,tpr,label="Federated Learning CNN, AUC="+str(auc))

#CNN
fpr, tpr, _ = metrics.roc_curve(CNN_label, CNN_pred)
auc = round(metrics.roc_auc_score(CNN_label, CNN_pred), 4)
plt.plot(fpr,tpr,label="Traditional CNN, AUC="+str(auc))

#FL RNN
fpr, tpr, _ = metrics.roc_curve(RNN_FL_label, RNN_FL_pred)
auc = round(metrics.roc_auc_score(RNN_FL_label, RNN_FL_pred), 4)
plt.plot(fpr,tpr,label="Federated Learning RNN, AUC="+str(auc))

#RNN
fpr, tpr, _ = metrics.roc_curve(RNN_label, RNN_pred)
auc = round(metrics.roc_auc_score(RNN_label, RNN_pred), 4)
plt.plot(fpr,tpr,label="Traditional RNN, AUC="+str(auc))

#add legend
plt.legend()
plt.show()

# %% [markdown]
# # ANN FL

# %%
data_files = ['cle_metadata', 'vir_metadata', 'hun_metadata', 'swi_metadata']

for file in data_files:
    data = pd.read_csv('../Metadata Learning/' + file + '.csv', index_col = 0)
    
    X = data.iloc[:, :-1]
    Y = data.iloc[:, -1]
    
    Y_binary = Y.apply(lambda x: 1 if x > 0 else 0)
    
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 42)
    
    train = pd.concat([X_train, y_train], axis=1)
    test = pd.concat([X_test, y_test], axis=1)
    
    train.to_csv('../TrainTestData/'+ file + "_train.csv")
    test.to_csv('../TrainTestData/' + file + "_test.csv")
    
#binarize the labels
lb = LabelBinarizer()

import pandas as pd

data_files = ['cle_metadata_train.csv','cle_metadata_test.csv','hun_metadata_train.csv','hun_metadata_test.csv','swi_metadata_train.csv','swi_metadata_test.csv','vir_metadata_train.csv','vir_metadata_test.csv']

datasets = {}

for file in data_files:
    data = pd.read_csv('../TrainTestData/' + file)
    
    X = data.iloc[:, :-1]
    Y = data.iloc[:, -1]
    
    Y_binary = Y.apply(lambda x: 1 if x > 0 else 0)
    
    # Extract the name from the file path
    name = file.split('.')[0]
    
    # Store the dataset components in a dictionary
    datasets[name] = {'X': X, 'Y': Y, 'Y_binary': Y_binary}

# Unpack the dictionary values in a loop
variables = ['cle', 'hun', 'swi', 'vir']
train_test = ['train', 'test']

for var in variables:
    for tt in train_test:
        X, Y, Y_binary = datasets[f'{var}_metadata_{tt}'].values()
        globals()[f'{var}_X_{tt}'] = X
        globals()[f'{var}_Y_{tt}'] = Y
        globals()[f'{var}_Y_{tt}_binary'] = Y_binary
        
X_test = pd.concat([cle_X_test,hun_X_test,swi_X_test,vir_X_test, swi_X_train])
y_test = pd.concat([cle_Y_test_binary,hun_Y_test_binary,swi_Y_test_binary,vir_Y_test_binary,swi_Y_train_binary])

X_train = pd.concat([cle_X_train,hun_X_train,vir_X_train])
y_train = pd.concat([cle_Y_train_binary,hun_Y_train_binary,vir_Y_train_binary])

class SimpleMLP:
    @staticmethod
    def build(shape, classes):
        model = Sequential()
        model.add(Dense(200, input_shape=(shape,)))
        model.add(Activation("relu"))
        model.add(Dense(200))
        model.add(Activation("relu"))
        model.add(Dense(classes))
        model.add(Activation("sigmoid"))
        return model

#create clients
clients = create_clients()

#process and batch the training data for each client
clients_batched = dict()
for (client_name, data) in clients.items():
    clients_batched[client_name] = batch_data(data)
    
#process and batch the test set  
test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

comms_round = 100
    
#create optimizer
lr = 0.01 
loss='sparse_categorical_crossentropy'
metrics = ['accuracy']
optimizer = tf.keras.optimizers.legacy.SGD(lr=lr, decay=lr / comms_round, momentum=0.9) 

#initialize global model
smlp_global = SimpleMLP()
global_model = smlp_global.build(64, 2)
        
#commence global training loop
for comm_round in range(comms_round):
            
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()
    
    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(clients_batched.keys())
    random.shuffle(client_names)
    
    #loop through each client and create new local model
    for client in client_names:
        smlp_local = SimpleMLP()
        local_model = smlp_local.build(64, 2)
        local_model.compile(loss=loss, 
                      optimizer=optimizer, 
                      metrics=metrics)
        
        #set local model weight to the weight of the global model
        local_model.set_weights(global_weights)
        
        #fit local model with client's data
        local_model.fit(clients_batched[client], epochs=1, verbose=0)
        
        #scale the model weights and add to list
        scaling_factor = weight_scalling_factor(clients_batched, client)
        scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
        scaled_local_weight_list.append(scaled_weights)
        
        #clear session to free memory after each communication round
        K.clear_session()
        
    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)
    
    #update global model 
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    for(X_test, Y_test) in test_batched:
        global_acc, global_loss = test_model(X_test, Y_test, global_model, comm_round)
        SGD_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(len(y_train)).batch(250)
        smlp_SGD = CNN()
        SGD_model = smlp_SGD.build(64, 2) 

        SGD_model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# fit the SGD training data to model
_ = SGD_model.fit(SGD_dataset, epochs=100, verbose=0)

#test the SGD global model and print out metrics
for(X_test, Y_test) in test_batched:
        SGD_acc, SGD_loss = test_model(X_test, Y_test, SGD_model, 1)
        
Y_predictions = np.argmax(SGD_model.predict(X_test),axis = 1)

ANN_FL_pred = Y_predictions.copy()
ANN_FL_label = Y_test
# Out:
# D:\Anaconda\envs\GPU\lib\site-packages\keras\optimizers\legacy\gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 12/12 [==============================] - 0s 935us/step
# comm_round: 0 | global_acc: 82.920% | global_loss: 0.5615326166152954
# 12/12 [==============================] - 0s 897us/step
# comm_round: 1 | global_acc: 77.410% | global_loss: 0.5753366947174072
# 12/12 [==============================] - 0s 940us/step
# comm_round: 2 | global_acc: 85.124% | global_loss: 0.5461835861206055
# 12/12 [==============================] - 0s 910us/step
# comm_round: 3 | global_acc: 82.369% | global_loss: 0.5555299520492554
# 12/12 [==============================] - 0s 861us/step
# comm_round: 4 | global_acc: 84.573% | global_loss: 0.5441838502883911
# 12/12 [==============================] - 0s 936us/step
# comm_round: 5 | global_acc: 84.298% | global_loss: 0.5471545457839966
# 12/12 [==============================] - 0s 936us/step
# comm_round: 6 | global_acc: 84.573% | global_loss: 0.5429501533508301
# 12/12 [==============================] - 0s 851us/step
# comm_round: 7 | global_acc: 84.573% | global_loss: 0.545437216758728
# 12/12 [==============================] - 0s 890us/step
# comm_round: 8 | global_acc: 84.573% | global_loss: 0.5432212352752686
# 12/12 [==============================] - 0s 995us/step
# comm_round: 9 | global_acc: 84.298% | global_loss: 0.5430024266242981
# 12/12 [==============================] - 0s 909us/step
# 12/12 [==============================] - 0s 1ms/step
# comm_round: 95 | global_acc: 86.501% | global_loss: 0.540980875492096
# 12/12 [==============================] - 0s 813us/step
# comm_round: 96 | global_acc: 86.777% | global_loss: 0.5388936400413513
# 12/12 [==============================] - 0s 1ms/step
# comm_round: 97 | global_acc: 86.501% | global_loss: 0.5399120450019836
# 12/12 [==============================] - 0s 909us/step
# comm_round: 98 | global_acc: 86.777% | global_loss: 0.5389772653579712
# 12/12 [==============================] - 0s 943us/step
# comm_round: 99 | global_acc: 86.501% | global_loss: 0.5388484001159668
# 12/12 [==============================] - 0s 6ms/step
# comm_round: 1 | global_acc: 84.848% | global_loss: 0.5340129137039185
# 12/12 [==============================] - 0s 6ms/step

# %%
from sklearn import metrics

plt.figure(0).clf()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
    
#FL CNN
fpr, tpr, _ = metrics.roc_curve(CNN_FL_label, CNN_FL_pred)
auc = round(metrics.roc_auc_score(CNN_FL_label, CNN_FL_pred), 4)
plt.plot([0, 1], [0, 1], 'k--')  # Random guessing line
plt.plot(fpr,tpr,label="Federated Learning CNN, AUC="+str(auc))

#CNN
fpr, tpr, _ = metrics.roc_curve(CNN_label, CNN_pred)
auc = round(metrics.roc_auc_score(CNN_label, CNN_pred), 4)
plt.plot(fpr,tpr,label="Traditional CNN, AUC="+str(auc))

#FL RNN
fpr, tpr, _ = metrics.roc_curve(RNN_FL_label, RNN_FL_pred)
auc = round(metrics.roc_auc_score(RNN_FL_label, RNN_FL_pred), 4)
plt.plot(fpr,tpr,label="Federated Learning RNN, AUC="+str(auc))

#RNN
fpr, tpr, _ = metrics.roc_curve(RNN_label, RNN_pred)
auc = round(metrics.roc_auc_score(RNN_label, RNN_pred), 4)
plt.plot(fpr,tpr,label="Traditional RNN, AUC="+str(auc))

#FL ANN
fpr, tpr, _ = metrics.roc_curve(ANN_FL_label, ANN_FL_pred)
auc = round(metrics.roc_auc_score(ANN_FL_label, ANN_FL_pred), 4)
plt.plot(fpr,tpr,label="Traditional RNN, AUC="+str(auc))

#add legend
plt.legend()
plt.show()

# %% [markdown]
# # ANN

# %%
Train = pd.read_csv('../TrainTestData/com_train.csv')
Test = pd.read_csv('../TrainTestData/com_test.csv')
    
X_train = Train.iloc[:,:-1]
Y_train = Train.iloc[:,-1]

X_test = Test.iloc[:,:-1]
Y_test = Test.iloc[:,-1]

#binarize the target
Y_train_binary = Y_train.apply(lambda x: 1 if x > 0 else 0)
Y_test_binary = Y_test.apply(lambda x: 1 if x > 0 else 0)

# define the model architecture
clf = MLPClassifier(activation = 'logistic', hidden_layer_sizes=(150))
    
clf.fit(X_train, Y_train_binary)
Y_pred = clf.predict(X_test)

ANN_pred = Y_pred
ANN_label = Y_test_binary
# Out:
# D:\Anaconda\envs\GPU\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn import metrics

plt.figure(0).clf()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
    
#FL CNN
fpr, tpr, _ = metrics.roc_curve(CNN_FL_label, CNN_FL_pred)
auc = round(metrics.roc_auc_score(CNN_FL_label, CNN_FL_pred), 4)
plt.plot([0, 1], [0, 1], 'k--')  # Random guessing line
plt.plot(fpr,tpr,label="Federated Learning CNN, AUC="+str(auc))

#CNN
fpr, tpr, _ = metrics.roc_curve(CNN_label, CNN_pred)
auc = round(metrics.roc_auc_score(CNN_label, CNN_pred), 4)
plt.plot(fpr,tpr,label="Traditional CNN, AUC="+str(auc))

#FL RNN
fpr, tpr, _ = metrics.roc_curve(RNN_FL_label, RNN_FL_pred)
auc = round(metrics.roc_auc_score(RNN_FL_label, RNN_FL_pred), 4)
plt.plot(fpr,tpr,label="Federated Learning RNN, AUC="+str(auc))

#RNN
fpr, tpr, _ = metrics.roc_curve(RNN_label, RNN_pred)
auc = round(metrics.roc_auc_score(RNN_label, RNN_pred), 4)
plt.plot(fpr,tpr,label="Traditional RNN, AUC="+str(auc))

#FL ANN
fpr, tpr, _ = metrics.roc_curve(ANN_FL_label, ANN_FL_pred)
auc = round(metrics.roc_auc_score(ANN_FL_label, ANN_FL_pred), 4)
plt.plot(fpr,tpr,label="Federated Learning RNN, AUC="+str(auc))

#=ANN
fpr, tpr, _ = metrics.roc_curve(ANN_label, ANN_pred)
auc = round(metrics.roc_auc_score(ANN_label, ANN_pred), 4)
plt.plot(fpr,tpr,label="Traditional RNN, AUC="+str(auc))

#add legend
plt.legend()
plt.show()
