# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
def dt(path_train,path_test):
    #Split the data
    Train = pd.read_csv(path_train)
    Test = pd.read_csv(path_test)
    
    X_train = Train.iloc[:,:-1]
    Y_train = Train.iloc[:,-1]

    X_test = Test.iloc[:,:-1]
    Y_test = Test.iloc[:,-1]

    #binarize the target
    Y_train_binary = Y_train.apply(lambda x: 1 if x > 0 else 0)
    Y_test_binary = Y_test.apply(lambda x: 1 if x > 0 else 0)

    #Desision Tree
    clf = tree.DecisionTreeClassifier(criterion='entropy')
    clf.fit(X_train, Y_train_binary)
    Y_predictions = clf.predict(X_test)
    cm = confusion_matrix(Y_predictions, Y_test_binary)
    print("Confusion Matrix is:")
    print(cm)
    def accuracy(confusion_matrix):
        diagonal_sum = confusion_matrix.trace()
        sum_of_all_elements = confusion_matrix.sum()
        return diagonal_sum / sum_of_all_elements
    print("Accuracy is : " + str(accuracy(cm)))
    
    print("Report")
    print(classification_report(Y_test_binary, Y_predictions, digits=4))
    
    #Visualization of the tree
    plt.figure(figsize=(25,20))
    tree.plot_tree(clf, filled=True, fontsize=10, max_depth= None,feature_names = list(X_train.columns), class_names = True)
    plt.show()

# %% [markdown]
# # Cleveland

# %%
path_train = '../cle_train.csv'
path_test = '../cle_test.csv'
dt(path_train,path_test)
# Out:
# Confusion Matrix is:
# [[42 10]
#  [11 30]]
# Accuracy is : 0.7741935483870968
# Report
#               precision    recall  f1-score   support
#
#            0     0.8077    0.7925    0.8000        53
#            1     0.7317    0.7500    0.7407        40
#
#     accuracy                         0.7742        93
#    macro avg     0.7697    0.7712    0.7704        93
# weighted avg     0.7750    0.7742    0.7745        93

# %% [markdown]
# # Hungarian

# %%
path_train = '../hun_train.csv'
path_test = '../hun_test.csv'
dt(path_train,path_test)
# Out:
# Confusion Matrix is:
# [[51 12]
#  [ 3 28]]
# Accuracy is : 0.8404255319148937
# Report
#               precision    recall  f1-score   support
#
#            0     0.8095    0.9444    0.8718        54
#            1     0.9032    0.7000    0.7887        40
#
#     accuracy                         0.8404        94
#    macro avg     0.8564    0.8222    0.8303        94
# weighted avg     0.8494    0.8404    0.8364        94

# %% [markdown]
# # Switzerland

# %%
path_train = '../swi_train.csv'
path_test = '../swi_test.csv'
dt(path_train,path_test)
# Out:
# Confusion Matrix is:
# [[ 1  6]
#  [ 1 33]]
# Accuracy is : 0.8292682926829268
# Report
#               precision    recall  f1-score   support
#
#            0     0.1429    0.5000    0.2222         2
#            1     0.9706    0.8462    0.9041        39
#
#     accuracy                         0.8293        41
#    macro avg     0.5567    0.6731    0.5632        41
# weighted avg     0.9302    0.8293    0.8708        41

# %% [markdown]
# # Virginia

# %%
path_train = '../vir_train.csv'
path_test = '../vir_test.csv'
dt(path_train,path_test)
# Out:
# Confusion Matrix is:
# [[ 9  6]
#  [11 36]]
# Accuracy is : 0.7258064516129032
# Report
#               precision    recall  f1-score   support
#
#            0     0.6000    0.4500    0.5143        20
#            1     0.7660    0.8571    0.8090        42
#
#     accuracy                         0.7258        62
#    macro avg     0.6830    0.6536    0.6616        62
# weighted avg     0.7124    0.7258    0.7139        62

# %% [markdown]
# # Combined

# %%
path_train = '../com_train.csv'
path_test = '../com_test.csv'
dt(path_train,path_test)
# Out:
# Confusion Matrix is:
# [[ 94  33]
#  [ 28 121]]
# Accuracy is : 0.7789855072463768
# Report
#               precision    recall  f1-score   support
#
#            0     0.7402    0.7705    0.7550       122
#            1     0.8121    0.7857    0.7987       154
#
#     accuracy                         0.7790       276
#    macro avg     0.7761    0.7781    0.7768       276
# weighted avg     0.7803    0.7790    0.7794       276
