# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
def dt(path_train,path_test):
    #Split the data
    Train = pd.read_csv(path_train)
    Test = pd.read_csv(path_test)
    
    X_train = Train.iloc[:,:-1]
    Y_train = Train.iloc[:,-1]

    X_test = Test.iloc[:,:-1]
    Y_test = Test.iloc[:,-1]

    #binarize the target
    Y_train_binary = Y_train.apply(lambda x: 1 if x > 0 else 0)
    Y_test_binary = Y_test.apply(lambda x: 1 if x > 0 else 0)

    #Desision Tree
    clf = tree.DecisionTreeClassifier(criterion='entropy')
    clf.fit(X_train, Y_train_binary)
    Y_predictions = clf.predict(X_test)
    cm = confusion_matrix(Y_predictions, Y_test_binary)
    print("Confusion Matrix is:")
    print(cm)
    def accuracy(confusion_matrix):
        diagonal_sum = confusion_matrix.trace()
        sum_of_all_elements = confusion_matrix.sum()
        return diagonal_sum / sum_of_all_elements
    print("Accuracy is : " + str(accuracy(cm)))
    
    print("Report")
    print(classification_report(Y_test_binary, Y_predictions, digits=4))
    
    #Visualization of the tree
    plt.figure(figsize=(25,20))
    tree.plot_tree(clf, filled=True, fontsize=10, max_depth= None,feature_names = list(X_train.columns), class_names = True)
    plt.show()

# %% [markdown]
# # Cleveland

# %%
path_train = '../cle_train.csv'
path_test = '../cle_test.csv'
dt(path_train,path_test)
# Out:
# Confusion Matrix is:
# [[39 10]
#  [14 30]]
# Accuracy is : 0.7419354838709677
# Report
#               precision    recall  f1-score   support
#
#            0     0.7959    0.7358    0.7647        53
#            1     0.6818    0.7500    0.7143        40
#
#     accuracy                         0.7419        93
#    macro avg     0.7389    0.7429    0.7395        93
# weighted avg     0.7468    0.7419    0.7430        93

# %% [markdown]
# # Hungarian

# %%
path_train = '../hun_train.csv'
path_test = '../hun_test.csv'
dt(path_train,path_test)
# Out:
# Confusion Matrix is:
# [[51 13]
#  [ 3 27]]
# Accuracy is : 0.8297872340425532
# Report
#               precision    recall  f1-score   support
#
#            0     0.7969    0.9444    0.8644        54
#            1     0.9000    0.6750    0.7714        40
#
#     accuracy                         0.8298        94
#    macro avg     0.8484    0.8097    0.8179        94
# weighted avg     0.8408    0.8298    0.8248        94

# %% [markdown]
# # Switzerland

# %%
path_train = '../swi_train.csv'
path_test = '../swi_test.csv'
dt(path_train,path_test)
# Out:
# Confusion Matrix is:
# [[ 1  4]
#  [ 1 35]]
# Accuracy is : 0.8780487804878049
# Report
#               precision    recall  f1-score   support
#
#            0     0.2000    0.5000    0.2857         2
#            1     0.9722    0.8974    0.9333        39
#
#     accuracy                         0.8780        41
#    macro avg     0.5861    0.6987    0.6095        41
# weighted avg     0.9346    0.8780    0.9017        41

# %% [markdown]
# # Virginia

# %%
path_train = '../vir_train.csv'
path_test = '../vir_test.csv'
dt(path_train,path_test)
# Out:
# Confusion Matrix is:
# [[ 8  3]
#  [12 39]]
# Accuracy is : 0.7580645161290323
# Report
#               precision    recall  f1-score   support
#
#            0     0.7273    0.4000    0.5161        20
#            1     0.7647    0.9286    0.8387        42
#
#     accuracy                         0.7581        62
#    macro avg     0.7460    0.6643    0.6774        62
# weighted avg     0.7526    0.7581    0.7347        62

# %% [markdown]
# # Combined

# %%
path_train = '../com_train.csv'
path_test = '../com_test.csv'
dt(path_train,path_test)
# Out:
# Confusion Matrix is:
# [[ 92  31]
#  [ 30 123]]
# Accuracy is : 0.7789855072463768
# Report
#               precision    recall  f1-score   support
#
#            0     0.7480    0.7541    0.7510       122
#            1     0.8039    0.7987    0.8013       154
#
#     accuracy                         0.7790       276
#    macro avg     0.7759    0.7764    0.7762       276
# weighted avg     0.7792    0.7790    0.7791       276
